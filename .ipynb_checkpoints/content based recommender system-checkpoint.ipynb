# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
df = pd.read_csv('final_Datasets.csv')

# %%
df
# Out:
#                                                    name  \
# 0                     7 Cups Sweet | 7 Cup Burfi Recipe
# 1     Aam Ka Murabba | Mango Murabba | Indian Mango ...
# 2     Aam Panna Recipe – With Boiled and Roasted Man...
# 3                                         Aamras Recipe
# 4                     Achari Paneer Recipe (With Gravy)
# ...                                                 ...
# 1043                                          poha idli
# 1044                                sama chawal khichdi
# 1045                                        sattu drink
# 1046                                      sprouts chaat
# 1047                                  sweet kozhukattai
#
#                                                   image  \
# 0     https://www.vegrecipesofindia.com/wp-content/u...
# 1     https://www.vegrecipesofindia.com/wp-content/u...
# 2     https://www.vegrecipesofindia.com/wp-content/u...
# 3     https://www.vegrecipesofindia.com/wp-content/u...
# 4     https://www.vegrecipesofindia.com/wp-content/u...
# ...                                                 ...
# 1043  https://www.vegrecipesofindia.com/wp-content/u...
# 1044  https://www.vegrecipesofindia.com/wp-content/u...
# 1045  https://www.vegrecipesofindia.com/wp-content/u...
# 1046  https://www.vegrecipesofindia.com/wp-content/u...
# 1047  https://www.vegrecipesofindia.com/wp-content/u...
#
#                                             description  prep_time  cook_time  \
# 0     7 Cup Burfi recipe is an easy and delicious So...   5minutes  25minutes
# 1     Aam Ka Murabba or Mango Murabba is a sweet and...  10minutes  15minutes
# 2     Aam ka panna is a cooling Indian summer drink ...  15minutes   5minutes
# 3     Aamrasis a popular and traditional mango delic...  15minutes   0minutes
# 4     Achari Paneer is a creamy as well as robust fl...  15minutes  30minutes
# ...                                                 ...        ...        ...
# 1043  Amazingly soft, light and fluffy aval idli mad...     9hours  15minutes
# 1044  Samvat rice khichdi recipe – savory porridge m...      1hour  35minutes
# 1045  This sattu sharbat is a cooling sweet drink ma...   5minutes        NaN
# 1046  Moong sprouts chaat is a quick, easy, tangy an...  20minutes  10minutes
# 1047  Sweet kozhukattai is a South Indian recipe var...      1hour  20minutes
#
#      total_time  servings_number    servings_unit       course  \
# 0     30minutes              4.0              NaN       Sweets
# 1     25minutes            450.0            grams    Side Dish
# 2     20minutes             12.0  Aam Panna Drink    Beverages
# 3     15minutes              4.0              NaN     Desserts
# 4     45minutes              4.0              NaN  Main Course
# ...         ...              ...              ...          ...
# 1043     9hours              4.0             to 5    Breakfast
# 1044      1hour              3.0             to 4  Main Course
# 1045   5minutes              3.0              NaN    Beverages
# 1046  30minutes              2.0             to 3       Snacks
# 1047      1hour             18.0     to 20 modaks       Sweets
#
#                        cuisine                diet  \
# 0     South Indian, Tamil Nadu          Vegetarian
# 1                 North Indian  Gluten Free, Vegan
# 2                       Indian               Vegan
# 3      Gujarati, Maharashtrian  Gluten Free, Vegan
# 4                 North Indian          Vegetarian
# ...                        ...                 ...
# 1043              South Indian                 NaN
# 1044              North Indian                 NaN
# 1045      Bihari, North Indian                 NaN
# 1046              North Indian               Vegan
# 1047              South Indian                 NaN
#
#                                             ingredients  \
# 0     ▢ ½ cup besan (gram flour) or 50 grams ▢ ½ cup...
# 1     ▢ 2  mangoes unripe, green and large – 400 gra...
# 2     For boiled aam panna – Recipe 1▢ 2  mangoes – ...
# 3     ▢ 400 grams mangoes or 2 large alphonso or 3 t...
# 4     Pickling spices▢ 1 teaspoon fennel seeds▢ 1 te...
# ...                                                 ...
# 1043  ▢ 1 cup idli dosa rice or parboiled rice or 20...
# 1044  ▢ 1 cup sama ke chawal (barnyard millet or sam...
# 1045  ▢ 1.5 litres chilled water or water at room te...
# 1046  ▢ 2 cups of sprouted moong beans▢ 1 small or m...
# 1047  for cooking chana dal▢ ½ cup chana dal (husked...
#
#                                            instructions  \
# 0     PreparationTake all the ingredients and keep t...
# 1     PreparationRinse and wipe dry the mangoes. The...
# 2     Making Boiled Aam Panna – Recipe 1Rinse the ra...
# 3     Making aamrasRinse the alphonso mangoes thorou...
# 4     Roasting Pickle SpicesFirst take the achari or...
# ...                                                 ...
# 1043  soakingIn a bowl or pan, take the following in...
# 1044  In a bowl, soak the sama chawal for an hour. D...
# 1045  Take chilled water in individual glasses. You ...
# 1046  cooking moong sproutsFirst you need to Sprout ...
# 1047  cooking chana dalRinse chana dal a couple of t...
#
#                                               nutrition
# 0     NutritionCalories: 512kcal | Carbohydrates: 59...
# 1     NutritionCalories: 70kcal | Carbohydrates: 18g...
# 2     NutritionCalories: 118kcal | Carbohydrates: 30...
# 3     NutritionCalories: 61kcal | Carbohydrates: 15g...
# 4     NutritionCalories: 321kcal | Carbohydrates: 9g...
# ...                                                 ...
# 1043                                                NaN
# 1044  NutritionCalories: 341kcal | Carbohydrates: 56...
# 1045                                                NaN
# 1046                                                NaN
# 1047                                                NaN
#
# [1048 rows x 14 columns]

# %%
import pandas as pd
import re

# 1. SETUP
df = pd.read_csv('final_Datasets.csv')
df = df.fillna('')

def parse_nutrition(text):
    try:
        cal_match = re.search(r'Calories:\s*(\d+)', str(text))
        calories = int(cal_match.group(1)) if cal_match else 9999
        prot_match = re.search(r'Protein:\s*(\d+)', str(text))
        protein = int(prot_match.group(1)) if prot_match else 0
        return calories, protein
    except:
        return 9999, 0

df[['calories', 'protein']] = df['nutrition'].apply(lambda x: pd.Series(parse_nutrition(x)))

location_map = {
    'Maharashtra': ['Maharashtrian', 'Mumbai', 'Konkani'],
    'Punjab': ['Punjabi', 'North Indian'],
    'South India': ['South Indian', 'Kerala', 'Tamil Nadu', 'Karnataka', 'Andhra'],
    'Gujarat': ['Gujarati'],
    'Bengal': ['Bengali']
}

# first fuction
def get_smart_recommendations(dish_name, user_location=None, user_diet=None):
    """
    1. Finds similar dishes (Content)
    2. Boosts score if cuisine matches location (Location)
    3. Removes dishes that don't match the diet (Diet)
    """
    
    # Validation
    if dish_name not in indices:
        return f"Recipe '{dish_name}' not found."
    
    idx = indices[dish_name]
    if isinstance(idx, pd.Series): idx = idx.iloc[0]

    # A. CONTENT STEP: Get raw similarity scores
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # B. LOCATION STEP: Apply Boosting
    # We create a new list of tuples (index, modified_score)
    boosted_scores = []
    
    # Get keywords for the user's location (if valid)
    loc_keywords = location_map.get(user_location, [])
    
    for i, score in sim_scores:
        # Skip the item itself
        if i == idx:
            continue
            
        recipe_cuisine = df.iloc[i]['cuisine']
        
        # Boost logic: Add 0.15 (15%) if it matches user location
        if loc_keywords and any(k in recipe_cuisine for k in loc_keywords):
            score += 0.15
            
        boosted_scores.append((i, score))

    # Sort based on the (possibly boosted) score
    boosted_scores = sorted(boosted_scores, key=lambda x: x[1], reverse=True)
    
    # C. DIET STEP: Apply Filtering
    final_indices = []
    
    for i, score in boosted_scores:
        recipe_diet = df.iloc[i]['diet']
        
        # Check Diet Constraint
        if user_diet:
            # "Vegetarian" logic: Allow "Vegetarian" OR "Vegan"
            if user_diet == "Vegetarian":
                if "Vegetarian" not in recipe_diet and "Vegan" not in recipe_diet:
                    continue # Skip this recipe
            # Strict logic for others (Vegan, Gluten Free, etc.)
            elif user_diet not in recipe_diet:
                continue # Skip this recipe
        
        # If it passes the filter, add to final list
        final_indices.append(i)
        
        # Stop after 10 recommendations
        if len(final_indices) >= 5:
            break

    # Return Result
    return df[['name', 'course', 'cuisine', 'diet']].iloc[final_indices]

# 2. THE RECOMMENDATION FUNCTION
def onboarding_recommendation(home_state, diet_type, is_gluten_free, diet_goal):
    
    # A. STRICT COURSE FILTER
    exclude_pattern = 'Dessert|Sweet|Spice Blend|Side Dish|Condiment|Spices'
    filtered_df = df[~df['course'].str.contains(exclude_pattern, case=False, na=False)].copy()

    # B. DIET FILTER
    if diet_type == 'Vegan':
        filtered_df = filtered_df[filtered_df['diet'].str.contains('Vegan', case=False)]
    elif diet_type == 'Vegetarian':
        filtered_df = filtered_df[filtered_df['diet'].str.contains('Vegetarian|Vegan', case=False)]
        
    if is_gluten_free:
        filtered_df = filtered_df[filtered_df['diet'].str.contains('Gluten Free', case=False)]

    # C. LOCATION BOOST
    loc_keywords = location_map.get(home_state, [])
    def calculate_relevance(row):
        score = 0
        if any(k in row['cuisine'] for k in loc_keywords):
            score += 100 
        return score
    filtered_df['relevance_score'] = filtered_df.apply(calculate_relevance, axis=1)

    # D. GOAL SORTING logic
    
    if diet_goal == 'weight_loss':
        # Prioritize Location, then Low Calories
        results = filtered_df.sort_values(by=['relevance_score', 'calories'], ascending=[False, True])
        
    elif diet_goal == 'weight_gain':
        # Prioritize Location, then High Calories
        results = filtered_df.sort_values(by=['relevance_score', 'calories'], ascending=[False, False])
        
    elif diet_goal == 'high_protein':
        # Prioritize Location, then Max Protein
        results = filtered_df.sort_values(by=['relevance_score', 'protein'], ascending=[False, False])
        
    elif diet_goal == 'lean_muscle': # <--- NEW GOAL for "Low Calorie + High Protein"
        
        # 1. Filter: Ensure it has significant protein first (e.g., > 10g)
        # We don't want to recommend a 20-calorie spice mix just because it has 1g protein (high ratio)
        lean_df = filtered_df[filtered_df['protein'] > 10].copy()
        
        # 2. Calculate Protein Density (Protein grams per Calorie)
        # (Add 1 to calories to avoid division by zero error)
        lean_df['protein_density'] = lean_df['protein'] / (lean_df['calories'] + 1)
        
        # 3. Sort by Relevance, then Density
        results = lean_df.sort_values(by=['relevance_score', 'protein_density'], ascending=[False, False])
        
    else: 
        results = filtered_df.sort_values(by='relevance_score', ascending=False)

    return results[['name', 'cuisine', 'protein', 'calories']].head(10)

# --- TEST SCENARIO ---
# User wants "Lean Muscle" food (High Protein, Low Calorie)
print("--- Recommendations for 'Lean Muscle' Goal ---")
print(onboarding_recommendation('North Indian', 'Vegetarian', False, 'lean_muscle'))
# Out:
# --- Recommendations for 'Lean Muscle' Goal ---
#                                                   name  \
# 927  Tandoori Gobi | Gobi Tikka | Tandoori Cauliflower
# 784                                        Ragda Chaat
# 542    Matar Kulcha | Matar Chaat – Delhi Style Recipe
# 421          Kali Dal | Punjabi Black Dal (Maa Ki Dal)
# 893                           Soya Chaap Masala Recipe
# 786                       Ragda Recipe (Simple & Easy)
# 894      Soya Chunks Fry (Kerala Style Meal Maker Fry)
# 708  Paneer Tikka Recipe (Tandoori Paneer Starter S...
# 54                      Amritsari Dal | Langarwali Dal
# 534         Masala Puri Recipe (Bangalore Style Chaat)
#
#                         cuisine  protein  calories
# 927       North Indian, Punjabi       11       133
# 784  Indian, Indian Street Food       13       195
# 542       North Indian, Punjabi       23       360
# 421             Indian, Punjabi       13       211
# 893                North Indian       16       265
# 786                      Indian       12       200
# 894        Kerala, South Indian       12       203
# 708                North Indian       17       316
# 54              Indian, Punjabi       15       285
# 534     Karnataka, South Indian       21       403

# %%
import pandas as pd
import re

# 1. SETUP
df = pd.read_csv('final_Datasets.csv')
df = df.fillna('')

def parse_nutrition(text):
    try:
        cal_match = re.search(r'Calories:\s*(\d+)', text)
        calories = int(cal_match.group(1)) if cal_match else 9999
        prot_match = re.search(r'Protein:\s*(\d+)', text)
        protein = int(prot_match.group(1)) if prot_match else 0
        return calories, protein
    except:
        return 9999, 0

df[['calories', 'protein']] = df['nutrition'].apply(lambda x: pd.Series(parse_nutrition(x)))

location_map = {
    # --- WEST INDIA ---
    'Maharashtra': ['Maharashtrian', 'Mumbai', 'Konkani', 'Kolhapuri', 'Malvani'],
    'Gujarat': ['Gujarati', 'Kathiyawadi'],
    'Goa': ['Goan', 'Konkani', 'Portuguese'],
    'Rajasthan': ['Rajasthani'],
    'Sindh': ['Sindhi'], 

    # --- NORTH INDIA ---
    'Punjab': ['Punjabi', 'Amritsari', 'North Indian'],
    'Uttar Pradesh': ['Uttar Pradesh', 'Awadhi', 'Banarasi', 'Mughlai', 'North Indian'],
    'Jammu & Kashmir': ['Kashmiri'],
    'Himachal Pradesh': ['Himachali', 'Pahari'],
    'Delhi': ['Delhi', 'Mughlai', 'Indian Street Food', 'North Indian'],
    'Madhya Pradesh': ['Indore', 'North Indian'], # Indore is famous for street food

    # --- SOUTH INDIA ---
    'Tamil Nadu': ['Tamil Nadu', 'Chettinad', 'South Indian'],
    'Kerala': ['Kerala', 'Malabar', 'South Indian'],
    'Karnataka': ['Karnataka', 'Mangalorean', 'Udupi', 'Coorg', 'South Indian'],
    'Andhra Pradesh & Telangana': ['Andhra', 'Hyderabadi', 'South Indian'],
    'South India (Generic)': ['South Indian'], # Fallback for general South Indian

    # --- EAST INDIA ---
    'West Bengal': ['Bengali', 'Kolkata'],
    'Odisha': ['Odisha', 'Oriya'],
    'Bihar': ['Bihari'],

    # --- OTHERS / SPECIAL COMMUNITIES ---
    'Parsi Community': ['Parsi'],
    'North East India': ['Tibetan', 'Nepali', 'Naga'],
    'International': ['Indo Chinese', 'Italian', 'Mexican', 'Thai', 'Chinese']
}

def get_smart_recommendations(dish_name, user_location=None, user_diet=None):
    """
    1. Finds similar dishes (Content)
    2. Boosts score if cuisine matches location (Location)
    3. Removes dishes that don't match the diet (Diet)
    """
    
    # Validation
    if dish_name not in indices:
        return f"Recipe '{dish_name}' not found."
    
    idx = indices[dish_name]
    if isinstance(idx, pd.Series): idx = idx.iloc[0]

    # A. CONTENT STEP: Get raw similarity scores
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # B. LOCATION STEP: Apply Boosting
    # We create a new list of tuples (index, modified_score)
    boosted_scores = []
    
    # Get keywords for the user's location (if valid)
    loc_keywords = location_map.get(user_location, [])
    
    for i, score in sim_scores:
        # Skip the item itself
        if i == idx:
            continue
            
        recipe_cuisine = df.iloc[i]['cuisine']
        
        # Boost logic: Add 0.15 (15%) if it matches user location
        if loc_keywords and any(k in recipe_cuisine for k in loc_keywords):
            score += 0.15
            
        boosted_scores.append((i, score))

    # Sort based on the (possibly boosted) score
    boosted_scores = sorted(boosted_scores, key=lambda x: x[1], reverse=True)
    
    # C. DIET STEP: Apply Filtering
    final_indices = []
    
    for i, score in boosted_scores:
        recipe_diet = df.iloc[i]['diet']
        
        # Check Diet Constraint
        if user_diet:
            # "Vegetarian" logic: Allow "Vegetarian" OR "Vegan"
            if user_diet == "Vegetarian":
                if "Vegetarian" not in recipe_diet and "Vegan" not in recipe_diet:
                    continue # Skip this recipe
            # Strict logic for others (Vegan, Gluten Free, etc.)
            elif user_diet not in recipe_diet:
                continue # Skip this recipe
        
        # If it passes the filter, add to final list
        final_indices.append(i)
        
        # Stop after 10 recommendations
        if len(final_indices) >= 5:
            break

    # Return Result
    return df[['name', 'course', 'cuisine', 'diet']].iloc[final_indices]

# 2. THE FUNCTION
def onboarding_recommendation(home_state, diet_type, is_gluten_free, diet_goal):
    
    # --- STEP 1: STRICT COURSE FILTER ---
    # We remove Desserts, Sweets, Spice Blends, Side Dishes, Condiments, and plain Spices
    # This ensures the user only sees "Real Food" (Main Course, Breakfast, Snacks)
    exclude_pattern = 'Dessert|Sweet|Spice Blend|Side Dish|Condiment|Spices'
    
    filtered_df = df[~df['course'].str.contains(exclude_pattern, case=False, na=False)].copy()

    # --- STEP 2: DIET FILTER ---
    if diet_type == 'Vegan':
        filtered_df = filtered_df[filtered_df['diet'].str.contains('Vegan', case=False)]
    elif diet_type == 'Vegetarian':
        filtered_df = filtered_df[filtered_df['diet'].str.contains('Vegetarian|Vegan', case=False)]
        
    # --- STEP 3: ALLERGY FILTER ---
    if is_gluten_free:
        filtered_df = filtered_df[filtered_df['diet'].str.contains('Gluten Free', case=False)]

    # --- STEP 4: LOCATION BOOST ---
    loc_keywords = location_map.get(home_state, [])
    
    def calculate_relevance(row):
        score = 0
        if any(k in row['cuisine'] for k in loc_keywords):
            score += 100 
        return score

    filtered_df['relevance_score'] = filtered_df.apply(calculate_relevance, axis=1)

    # --- STEP 5: GOAL SORT ---
    if diet_goal == 'weight_loss':
        results = filtered_df.sort_values(by=['relevance_score', 'calories'], ascending=[False, True])
    elif diet_goal == 'weight_gain':
        results = filtered_df.sort_values(by=['relevance_score', 'calories'], ascending=[False, False])
    elif diet_goal == 'high_protein':
        results = filtered_df.sort_values(by=['relevance_score', 'protein'], ascending=[False, False])
    else: 
        results = filtered_df.sort_values(by='relevance_score', ascending=False)

    return results[['name', 'course', 'cuisine', 'calories']].head(5)

# --- TEST ---
print("test 1")
print("Scenario 1: Just Content (No preferences)")
print(get_smart_recommendations("Veg Kolhapuri Recipe"))

print("\nScenario 2: User in South Indian (Location Boost)")
print(get_smart_recommendations("Veg Kolhapuri Recipe", user_location="South Indian"))

print("\nScenario 3: User in Uttar Pradesh but VEGAN (Location + Diet Filter)")
print(get_smart_recommendations("Veg Kolhapuri Recipe", user_location="Uttar Pradesh", user_diet="Vegan"))
print("test 2")
print(onboarding_recommendation('North Indian', 'Vegetarian', False, 'weight_gain'))
# Out:
# test 1
# Scenario 1: Just Content (No preferences)
#                                                name       course  \
# 692                                Paneer Kolhapuri  Main Course
# 342                              Goda Masala Recipe  Spice Blend
# 705       Paneer Pulao Recipe | One Pot Paneer Rice  Main Course
# 999  Veg Kurma Recipe (Hotel Style Vegetable Korma)  Main Course
# 8             Akkha Masoor Recipe (Kolhapuri style)  Main Course
#
#                       cuisine                     diet
# 692                 Kolhapuri               Vegetarian
# 342             Maharashtrian                    Vegan
# 705                    Indian               Vegetarian
# 999  South Indian, Tamil Nadu  Gluten Free, Vegetarian
# 8    Kolhapuri, Maharashtrian       Gluten Free, Vegan
#
# Scenario 2: User in South Indian (Location Boost)
#                                                name       course  \
# 692                                Paneer Kolhapuri  Main Course
# 342                              Goda Masala Recipe  Spice Blend
# 705       Paneer Pulao Recipe | One Pot Paneer Rice  Main Course
# 999  Veg Kurma Recipe (Hotel Style Vegetable Korma)  Main Course
# 8             Akkha Masoor Recipe (Kolhapuri style)  Main Course
#
#                       cuisine                     diet
# 692                 Kolhapuri               Vegetarian
# 342             Maharashtrian                    Vegan
# 705                    Indian               Vegetarian
# 999  South Indian, Tamil Nadu  Gluten Free, Vegetarian
# 8    Kolhapuri, Maharashtrian       Gluten Free, Vegan
#
# Scenario 3: User in Uttar Pradesh but VEGAN (Location + Diet Filter)
#                                             name       course  \
# 342                           Goda Masala Recipe  Spice Blend
# 365                 Homemade Sabji Masala Recipe  Spice Blend
# 137  Biryani Masala Recipe | Pulao Masala Powder  Spice Blend
# 329   Garam Masala Recipe (Homemade & Authentic)  Spice Blend
# 138                          Biryani Rice Recipe  Main Course
#
#                   cuisine                            diet
# 342         Maharashtrian                           Vegan
# 365          North Indian              Gluten Free, Vegan
# 137          North Indian              Gluten Free, Vegan
# 329  Indian, North Indian              Gluten Free, Vegan
# 138          North Indian  Gluten Free, Vegan, Vegetarian
# test 2
#                       name                     course             cuisine  \
# 18        Aloo Chana Chaat                     Snacks              Indian
# 44        Aloo Tikki Chole                     Snacks        North Indian
# 70   Aval Upma | Poha Upma  Breakfast, Brunch, Snacks        South Indian
# 136         Bhutte ka kees                     Snacks  Indian Street Food
# 224            Chilli Idli                     Snacks        Indo Chinese
#
#      calories
# 18       9999
# 44       9999
# 70       9999
# 136      9999
# 224      9999

# %%
df.tail(50)['name']
# Out:
# 998                                  Veg Kolhapuri Recipe
# 999        Veg Kurma Recipe (Hotel Style Vegetable Korma)
# 1000                                         Veg Lollipop
# 1001                                       Veg Makhanwala
# 1002               Veg Momos Recipe (Indian Street Style)
# 1003           Veg Noodles (Stir Fried Vegetable Noodles)
# 1004               Veg Pulao Recipe (Mix Vegetable Pulav)
# 1005                      Veg Raita | Mix Vegetable Raita
# 1006                            Veg Sagu | Vegetable Sagu
# 1007          Vegetable Biryani Recipe (Restaurant Style)
# 1008                                       Vegetable Chop
# 1009                               Vegetable Curry Recipe
# 1010    Vegetable Dum Biryani | Hyderabadi Veg Dum Bir...
# 1011              Vegetable Pakora Recipe (Crispy & Easy)
# 1012              Vegetable Stew | Kerala Veg Stew Recipe
# 1013                Vellarikka pachadi | Cucumber pachadi
# 1014       Ven Pongal Recipe | Khara Pongal | Ghee Pongal
# 1015            Vendakkai Poriyal | Ladies Finger Poriyal
# 1016                                     Vendakkai Sambar
# 1017                          Vendhaya Dosai | Methi Dosa
# 1018                                       Vengaya Sambar
# 1019                                   Vermicelli Biryani
# 1020                       Vindaloo Recipe With Mushrooms
# 1021                        Vrat Wale Aloo | Vrat ke aloo
# 1022    Vrat ki Kadhi | Rajgira Kadhi for Fasting | Fa...
# 1023              Wheat Dosa Recipe (Crispy Godhuma Dosa)
# 1024                             Wheat Halwa | Atta Halwa
# 1025                   Wheat Momos | Atta Momos (Healthy)
# 1026                         White Dhokla | Khatta Dhokla
# 1027    Whole Masoor Dal | Brown Lentils (Sabut Masoor...
# 1028                 Wood Apple Juice | Wood Apple Recipe
# 1029                     Yakhni Pulao Recipe (Vegetarian)
# 1030                          Yam Chips (Jimikand Recipe)
# 1031              Yam Fry Recipe | Konkan Style Suran Fry
# 1032     Zarda – Meethe Chawal Recipe (Indian Sweet Rice)
# 1033                                        bendakaya fry
# 1034                                     bendakaya pulusu
# 1035                                 davangere benne dosa
# 1036                                   dudhi bhopla bhaji
# 1037                                         katachi amti
# 1038                                       khandvi recipe
# 1039                                    ladies finger fry
# 1040                                       lauki ki kheer
# 1041                                         luchi recipe
# 1042                                          malai kulfi
# 1043                                            poha idli
# 1044                                  sama chawal khichdi
# 1045                                          sattu drink
# 1046                                        sprouts chaat
# 1047                                    sweet kozhukattai
# Name: name, dtype: object

# %%
# 1. Load the Dataset
# Ensure the file 'final_Datasets.csv' is in the same folder as this script


print(f"Loaded {len(df)} recipes successfully.")

# 2. Data Cleaning & Preprocessing
# We replace missing values with empty strings so they don't cause errors
features = ['ingredients', 'description', 'cuisine', 'course', 'diet', 'name']
for feature in features:
    df[feature] = df[feature].fillna('')

# 3. Create a "Content Soup"
# We combine all important text features into one long string (soup) for each recipe.
# This gives the algorithm a full picture of the dish (what it is, how it's made, what's inside).
def create_soup(x):
    return (x['name'] + ' ' + 
            x['ingredients'] + ' ' + 
            x['description'] + ' ' + 
            x['cuisine'] + ' ' + 
            x['diet'] + ' ' + 
            x['course'])

df['soup'] = df.apply(create_soup, axis=1)

# 4. TF-IDF Vectorization
# Convert the text 'soup' into a matrix of numbers.
# stop_words='english' removes common words like "the", "a", "in".
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['soup'])

# 5. Compute Cosine Similarity
# Calculate the similarity score (0 to 1) between every pair of recipes.
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# 6. Create Index Mapping
# This allows us to find the numeric index of a recipe using its name.
indices = pd.Series(df.index, index=df['name']).drop_duplicates()

# 7. Define the Recommendation Function
def get_recommendations(title, cosine_sim=cosine_sim):
    # Check if title exists
    if title not in indices:
        return f"Recipe '{title}' not found in the dataset."
    
    # Get the index of the recipe
    idx = indices[title]
    
    # Handle cases where multiple recipes might have the exact same name
    if isinstance(idx, pd.Series):
        idx = idx.iloc[0]

    # Get similarity scores for all other recipes
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort recipes by similarity score (highest first)
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get top 10 similar recipes (skipping the first one, which is the recipe itself)
    sim_scores = sim_scores[1:11]
    
    # Get the recipe indices
    recipe_indices = [i[0] for i in sim_scores]

    # Return the top 10 recommendations
    return df[['name', 'cuisine', 'diet', 'course']].iloc[recipe_indices]

# --- TEST THE SYSTEM ---
# Let's try it with a dish from your dataset
# Out:
# Loaded 1048 recipes successfully.

# %%
test_dish = "tomato"
print(f"\nFinding recommendations for: {test_dish}")
recommendations = get_recommendations(test_dish)
print(recommendations)
# Out:
# Finding recommendations for: tomato
# Recipe 'tomato' not found in the dataset.

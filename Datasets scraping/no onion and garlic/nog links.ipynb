# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
import pandas as pd
from IPython.display import HTML

# %%
final_dict = {}
no_of_page = 5
for i in range(1 ,no_of_page + 1):
    
    #opening the page
    n = str(i)
    ext = '.html'
    file_path = 'nog_' + n + ext
    with open(file_path, 'r', encoding='utf-8') as f:
        html_content = f.read()
        
    #scraping the page    
    soup = BeautifulSoup(html_content, 'lxml')
    t = soup.find_all('h2', class_='entry-title')
    dict = {}
    for j in t:
        x = j.find('a')
        dict[x.get_text()] = x.get('href')
    #merging the disctt to final dict
    final_dict.update(dict)
    print(f"page " + str(i) + " done")
# Out:
# page 1 done
# page 2 done
# page 3 done
# page 4 done
# page 5 done

# %%
len(final_dict)
# Out:
# 289

# %%
df_index = pd.DataFrame.from_dict(final_dict, orient='index')

# %%
df_index
# Out:
#                                                                                                     0
# Idli Recipe & Idli Batter – Tips That Actually ...  https://www.vegrecipesofindia.com/idli-recipe-...
# Samosa Recipe (Better Than Takeout)                 https://www.vegrecipesofindia.com/samosa-recip...
# Khaman Dhokla Recipe (Instant Gujarati Khaman)      https://www.vegrecipesofindia.com/khaman-dhokl...
# Aloo Paratha Recipe (Punjabi Style)                 https://www.vegrecipesofindia.com/aloo-paratha...
# Rava Idli (Easy and No Fermentation)                https://www.vegrecipesofindia.com/rava-idli-re...
# ...                                                                                               ...
# Madra Recipe | Himachali Rajma Madra Recipe         https://www.vegrecipesofindia.com/rajma-madra-...
# Fried Breadfruit Recipe                             https://www.vegrecipesofindia.com/breadfruit-r...
# Peanut Rice Recipe (South Indian Style)             https://www.vegrecipesofindia.com/peanut-rice-...
# Majjiga | Sambaram | Neer Mor                       https://www.vegrecipesofindia.com/neer-mor-rec...
# Arbi ke patte ke pakode                             https://www.vegrecipesofindia.com/arbi-patta-p...
#
# [289 rows x 1 columns]

# %%
df_index.to_csv('nog_links.csv')

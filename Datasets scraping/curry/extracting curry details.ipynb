# %%
import pandas as pd
import numpy as mp
import requests
from bs4 import BeautifulSoup

# %%
import time

# %%
df = pd.read_csv('curry_links.csv')

# %%
df.rename(columns={'0': 'link'}, inplace=True)

# %%
link = df['link']

# %%
name = []
image = []
description = []
prep_time = []
cook_time = []
total_time = []
servings_number = []
servings_unit = []
course = []
cuisine = []
diet = []
ingredients = []
instructions = []
nutrition = []

# %%
count = 1;
for url in link:
    print(url)
    time.sleep(1)
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://www.google.com/'
    }
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    a = soup.find('div', class_='wprm-recipe-template-dassanas-veg-recipes-header-text')
    try:
        name.append(a.find('h2', class_='wprm-recipe-name wprm-block-text-bold').get_text(strip=True))
    except:
        continue
    try:
        # image.append(a.find("div", class_="wprm-recipe-image").find("img").get('data-lazy-src'))
        img_tag = soup.select_one(".wprm-recipe-image img")

        if img_tag:
            img_url = (
                img_tag.get("data-lazy-src")
                or img_tag.get("data-lazy-srcset")
                or img_tag.get("srcset")
            )
            image.append(img_url)
    except:
        image.append(None)
    description.append(a.find('div', class_='wprm-recipe-summary wprm-block-text-normal').get_text(strip=True))
    soup1 = soup.find('div', class_='wprm-recipe-template-dassanas-veg-recipes-meta')
    try:
        prep_time.append(soup1.find('span', class_='wprm-recipe-prep_time').get_text(strip=True))
    except:
        prep_time.append(None)
    try:
        cook_time.append(soup1.find('span', class_='wprm-recipe-cook_time').get_text(strip=True))
    except:
        cook_time.append(None)
    try:
        total_time.append(soup1.find('span', class_='wprm-recipe-total_time').get_text(strip=True))
    except:
        total_time.append(None)
    try:
        servings_number.append(soup1.find('span', class_='wprm-recipe-servings').get_text(strip=True))
    except:
        servings_number.append(None)
    try:
        servings_unit.append(soup1.find('span', class_='wprm-recipe-servings-unit').get_text(strip=True))
    except:
        servings_unit.append(None)
    try:
        course.append(soup1.find('span', class_='wprm-recipe-course').get_text(strip=True))
    except:
        course.append(None)
    try:
        cuisine.append(soup1.find('span', class_='wprm-recipe-cuisine').get_text(strip=True))
    except:
        cuisine.append(None)
    try:
        diet.append(soup1.find('span', class_='wprm-recipe-suitablefordiet').get_text(strip=True))
    except:
        diet.append(None)
    try:
        ingredients.append(soup.find('div', class_='wprm-recipe-ingredient-group').get_text())
    except:
        ingredients.append(None)
    try:
        instructions.append(soup.find('div', class_='wprm-internal-container wprm-internal-container-instructions').get_text())
    except:
        instructions.append(None)
    try:
        nutrition.append(soup.find('div', class_='wprm-nutrition-label-shortcode-container').get_text())
    except:
        nutrition.append(None)

    print(count)
    print(a.find('h2', class_='wprm-recipe-name wprm-block-text-bold').text)
    count += 1
# Out:
# https://www.vegrecipesofindia.com/paneer-butter-masala/
# 1
# Paneer Butter Masala Recipe
# https://www.vegrecipesofindia.com/palak-paneer/
# 2
# Palak Paneer Recipe (Spinach Sauce & Paneer)
# https://www.vegrecipesofindia.com/matar-paneer/
# 3
# https://www.vegrecipesofindia.com/bendakaya-pulusu-recipe/
# 137
# bendakaya pulusu
# https://www.vegrecipesofindia.com/jain-palak-paneer/
# 138
# Jain Palak Paneer
# https://www.vegrecipesofindia.com/soya-chunks-fry/
# 139
# Soya Chunks Fry (Kerala Style Meal Maker Fry)
# https://www.vegrecipesofindia.com/paneer-kalimirch-recipe/
# 140
# Paneer Kali Mirch Recipe

# %%
df = pd.DataFrame({
    'name': name,
    'image' : image,
    'description': description,
    'prep_time': prep_time,
    'cook_time': cook_time,
    'total_time': total_time,
    'servings_number': servings_number,
    'servings_unit': servings_unit,
    'course': course,
    'cuisine': cuisine,
    'diet': diet,
    'ingredients': ingredients,
    'instructions': instructions,
    'nutrition': nutrition
})

# %%
print("name:", len(name))
print("description:", len(description))
print("prep_time:", len(prep_time))
print("cook_time:", len(cook_time))
print("total_time:", len(total_time))
print("servings_number:", len(servings_number))
print("servings_unit:", len(servings_unit))
print("course:", len(course))
print("cuisine:", len(cuisine))
print("diet:", len(diet))
print("ingredients:", len(ingredients))
print("instructions:", len(instructions))
print("nutrition:", len(nutrition))
# Out:
# name: 140
# description: 140
# prep_time: 140
# cook_time: 140
# total_time: 140
# servings_number: 140
# servings_unit: 140
# course: 140
# cuisine: 140
# diet: 140
# ingredients: 140
# instructions: 140
# nutrition: 140

# %%
df.to_csv('curry_details.csv')

# %%
df
# Out:
#                                                   name  \
# 0                          Paneer Butter Masala Recipe
# 1         Palak Paneer Recipe (Spinach Sauce & Paneer)
# 2          Matar Paneer Recipe (Punjabi Mutter Paneer)
# 3       Rajma Recipe | Rajma Masala (Restaurant Style)
# 4    Malai Kofta Recipe (Restaurant Style Paneer Ko...
# ..                                                 ...
# 135                                  Aloo Matar Paneer
# 136                                   bendakaya pulusu
# 137                                  Jain Palak Paneer
# 138      Soya Chunks Fry (Kerala Style Meal Maker Fry)
# 139                           Paneer Kali Mirch Recipe
#
#                                                  image  \
# 0    https://www.vegrecipesofindia.com/wp-content/u...
# 1    https://www.vegrecipesofindia.com/wp-content/u...
# 2    https://www.vegrecipesofindia.com/wp-content/u...
# 3    https://www.vegrecipesofindia.com/wp-content/u...
# 4    https://www.vegrecipesofindia.com/wp-content/u...
# ..                                                 ...
# 135  https://www.vegrecipesofindia.com/wp-content/u...
# 136  https://www.vegrecipesofindia.com/wp-content/u...
# 137  https://www.vegrecipesofindia.com/wp-content/u...
# 138  https://www.vegrecipesofindia.com/wp-content/u...
# 139  https://www.vegrecipesofindia.com/wp-content/u...
#
#                                            description  prep_time  cook_time  \
# 0    Paneer Butter Masala is one of the most popula...  20minutes  20minutes
# 1    Palak Paneer that is delicious, smooth and cre...  30minutes  10minutes
# 2    Matar Paneer is a classic Punjabi dish consist...  15minutes  15minutes
# 3    This Rajma recipe is a creamy, tangy and spice...     9hours  45minutes
# 4    Malai Kofta is a delicious recipe of fried bal...  45minutes  45minutes
# ..                                                 ...        ...        ...
# 135  Aloo matar paneer is tasty curry made with pot...  10minutes  20minutes
# 136  Bendakaya pulusu recipe is Andhra style okra c...  20minutes  30minutes
# 137  A very easy and tasty recipe of Jain Palak Pan...  30minutes  10minutes
# 138  This Soya Chunks Fry recipe is filled with rob...  20minutes  20minutes
# 139  Paneer Kalimirch is one of the lesser-known bu...  15minutes  15minutes
#
#     total_time servings_number servings_unit       course  \
# 0    40minutes               4          None  Main Course
# 1    40minutes               4          None  Main Course
# 2    30minutes               4          None  Main Course
# 3       9hours               5          None  Main Course
# 4        1hour               4          None  Main Course
# ..         ...             ...           ...          ...
# 135  30minutes               4          None  Main Course
# 136  50minutes               3          None  Main Course
# 137  40minutes               4          None  Main Course
# 138  40minutes               4          None  Main Course
# 139  30minutes               3          None  Main Course
#
#                    cuisine                     diet  \
# 0             North Indian  Gluten Free, Vegetarian
# 1             North Indian               Vegetarian
# 2    North Indian, Punjabi  Gluten Free, Vegetarian
# 3    North Indian, Punjabi               Vegetarian
# 4     Indian, North Indian               Vegetarian
# ..                     ...                      ...
# 135  North Indian, Punjabi               Vegetarian
# 136                 Andhra                     None
# 137                   Jain               Vegetarian
# 138   Kerala, South Indian        Vegan, Vegetarian
# 139  North Indian, Punjabi               Vegetarian
#
#                                            ingredients  \
# 0    For cashew paste▢ 18 to 20 cashews – whole▢ ⅓ ...
# 1    For spinach puree▢ 250 grams spinach or 5 to 6...
# 2    Main ingredients▢ 3 tablespoons oil or ghee▢ ½...
# 3    For pressure cooking▢ 1 cup rajma – 200 grams ...
# 4    For kofta▢ 100 grams Paneer or 1 cup grated pa...
# ..                                                 ...
# 135  for masala paste▢ 1 large onion  or 85 grams o...
# 136  for tamarind pulp▢ 1 tablespoon tightly packed...
# 137  For spinach puree▢ 4 cups spinach – tightly pa...
# 138  To Prep Soya Chunks▢ 1 cup soya chunks – meal ...
# 139  For onion paste▢ 1  inch  cinnamon▢ 2  green c...
#
#                                           instructions  \
# 0    PreparationSoak cashews in a hot water for 15 ...
# 1    Making spinach pureeRinse the palak or spinach...
# 2    Making Masala PasteIn a grinder or blender tak...
# 3    SoakingRinse and soak the rajma (kidney beans)...
# 4    Making paneer koftaMix all the ingredients men...
# ..                                                 ...
# 135  making onion-tomato masala pasteIn a blender o...
# 136  preparation for bendakaya pulusuSoak tamarind ...
# 137  Blanching and making spinach pureeFirst soak c...
# 138  Prep Soya ChunksFirst, add the soya chunks or ...
# 139  PreparationTake ½ teaspoon black pepper in a m...
#
#                                              nutrition
# 0    NutritionCalories: 307kcal | Carbohydrates: 9g...
# 1    NutritionCalories: 265kcal | Carbohydrates: 8g...
# 2    NutritionCalories: 359kcal | Carbohydrates: 13...
# 3    NutritionCalories: 210kcal | Carbohydrates: 28...
# 4    NutritionCalories: 539kcal | Carbohydrates: 40...
# ..                                                 ...
# 135  NutritionCalories: 308kcal | Carbohydrates: 19...
# 136  NutritionCalories: 141kcal | Carbohydrates: 18...
# 137  NutritionCalories: 247kcal | Carbohydrates: 7g...
# 138  NutritionCalories: 203kcal | Carbohydrates: 15...
# 139  NutritionCalories: 375kcal | Carbohydrates: 11...
#
# [140 rows x 14 columns]

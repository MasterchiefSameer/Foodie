# %%
import pandas as pd
import numpy as mp
import requests
from bs4 import BeautifulSoup

# %%
import time

# %%
df = pd.read_csv('raita_links.csv')

# %%
df.rename(columns={'0': 'link'}, inplace=True)

# %%
link = df['link']

# %%
name = []
image = []
description = []
prep_time = []
cook_time = []
total_time = []
servings_number = []
servings_unit = []
course = []
cuisine = []
diet = []
ingredients = []
instructions = []
nutrition = []

# %%
count = 1;
for url in link:
    print(url)
    time.sleep(1)
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://www.google.com/'
    }
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    a = soup.find('div', class_='wprm-recipe-template-dassanas-veg-recipes-header-text')
    try:
        name.append(a.find('h2', class_='wprm-recipe-name wprm-block-text-bold').get_text(strip=True))
    except:
        continue
    try:
        # image.append(a.find("div", class_="wprm-recipe-image").find("img").get('data-lazy-src'))
        img_tag = soup.select_one(".wprm-recipe-image img")

        if img_tag:
            img_url = (
                img_tag.get("data-lazy-src")
                or img_tag.get("data-lazy-srcset")
                or img_tag.get("srcset")
            )
            image.append(img_url)
    except:
        image.append(None)
    description.append(a.find('div', class_='wprm-recipe-summary wprm-block-text-normal').get_text(strip=True))
    soup1 = soup.find('div', class_='wprm-recipe-template-dassanas-veg-recipes-meta')
    try:
        prep_time.append(soup1.find('span', class_='wprm-recipe-prep_time').get_text(strip=True))
    except:
        prep_time.append(None)
    try:
        cook_time.append(soup1.find('span', class_='wprm-recipe-cook_time').get_text(strip=True))
    except:
        cook_time.append(None)
    try:
        total_time.append(soup1.find('span', class_='wprm-recipe-total_time').get_text(strip=True))
    except:
        total_time.append(None)
    try:
        servings_number.append(soup1.find('span', class_='wprm-recipe-servings').get_text(strip=True))
    except:
        servings_number.append(None)
    try:
        servings_unit.append(soup1.find('span', class_='wprm-recipe-servings-unit').get_text(strip=True))
    except:
        servings_unit.append(None)
    try:
        course.append(soup1.find('span', class_='wprm-recipe-course').get_text(strip=True))
    except:
        course.append(None)
    try:
        cuisine.append(soup1.find('span', class_='wprm-recipe-cuisine').get_text(strip=True))
    except:
        cuisine.append(None)
    try:
        diet.append(soup1.find('span', class_='wprm-recipe-suitablefordiet').get_text(strip=True))
    except:
        diet.append(None)
    try:
        ingredients.append(soup.find('div', class_='wprm-recipe-ingredient-group').get_text())
    except:
        ingredients.append(None)
    try:
        instructions.append(soup.find('div', class_='wprm-internal-container wprm-internal-container-instructions').get_text())
    except:
        instructions.append(None)
    try:
        nutrition.append(soup.find('div', class_='wprm-nutrition-label-shortcode-container').get_text())
    except:
        nutrition.append(None)

    print(count)
    print(a.find('h2', class_='wprm-recipe-name wprm-block-text-bold').text)
    count += 1
# Out:
# https://www.vegrecipesofindia.com/boondi-raita/
# 1
# Boondi Raita Recipe (Classic)
# https://www.vegrecipesofindia.com/pineapple-raita-recipe-pineapple-raita/
# 2
# Pineapple Raita
# https://www.vegrecipesofindia.com/onion-tomato-raita/
# 3
# Onion Raita | Tomato Raita | Onion Tomato Raita
# https://www.vegrecipesofindia.com/beetroot-carrot-raita-beetroot-raita/
# 4
# Beetroot Raita
# https://www.vegrecipesofindia.com/burhani-raita-recipe-boorani-raita/
# 5
# Burani Raita | Hyderabadi Burhani Raita
# https://www.vegrecipesofindia.com/cucumber-raita-recipe/
# 6
# Cucumber Raita Recipe (Indian Raita)
# https://www.vegrecipesofindia.com/makhana-raita-recipe/
# 7
# Makhana Raita
# https://www.vegrecipesofindia.com/aloo-raita-recipe-potato-raita/
# 8
# Aloo Raita
# https://www.vegrecipesofindia.com/vegetable-raita-recipe/
# 9
# Veg Raita | Mix Vegetable Raita
# https://www.vegrecipesofindia.com/lauki-raita-recipe-dudhi-raita/
# 10
# Lauki ka Raita
# https://www.vegrecipesofindia.com/carrot-raita-recipe-gajar-raita/
# 11
# Carrot Raita
# https://www.vegrecipesofindia.com/mango-raita-recipe-mango-raita/
# 12
# Mango Raita Recipe
# https://www.vegrecipesofindia.com/cucumber-pachadi-recipe/
# 13
# Vellarikka pachadi | Cucumber pachadi
# https://www.vegrecipesofindia.com/fruit-raita-recipe/
# 14
# Fruit Raita
# https://www.vegrecipesofindia.com/mint-raita-recipe-pudina-raita/
# 15
# Mint Raita | Pudina Raita
# https://www.vegrecipesofindia.com/masala-raita-recipe/
# 16
# Masala Raita | Dahi Raita
# https://www.vegrecipesofindia.com/pineapple-pachadi-recipe/
# 17
# Pineapple Pachadi
# https://www.vegrecipesofindia.com/palak-raita-vegan-palak-raita/
# 18
# Palak Raita | Spinach Raita

# %%
df = pd.DataFrame({
    'name': name,
    'image' : image,
    'description': description,
    'prep_time': prep_time,
    'cook_time': cook_time,
    'total_time': total_time,
    'servings_number': servings_number,
    'servings_unit': servings_unit,
    'course': course,
    'cuisine': cuisine,
    'diet': diet,
    'ingredients': ingredients,
    'instructions': instructions,
    'nutrition': nutrition
})

# %%
print("name:", len(name))
print("description:", len(description))
print("prep_time:", len(prep_time))
print("cook_time:", len(cook_time))
print("total_time:", len(total_time))
print("servings_number:", len(servings_number))
print("servings_unit:", len(servings_unit))
print("course:", len(course))
print("cuisine:", len(cuisine))
print("diet:", len(diet))
print("ingredients:", len(ingredients))
print("instructions:", len(instructions))
print("nutrition:", len(nutrition))
# Out:
# name: 18
# description: 18
# prep_time: 18
# cook_time: 18
# total_time: 18
# servings_number: 18
# servings_unit: 18
# course: 18
# cuisine: 18
# diet: 18
# ingredients: 18
# instructions: 18
# nutrition: 18

# %%
df.to_csv('raita_details.csv')

# %%
df
# Out:
#                                                name  \
# 0                     Boondi Raita Recipe (Classic)
# 1                                   Pineapple Raita
# 2   Onion Raita | Tomato Raita | Onion Tomato Raita
# 3                                    Beetroot Raita
# 4           Burani Raita | Hyderabadi Burhani Raita
# 5              Cucumber Raita Recipe (Indian Raita)
# 6                                     Makhana Raita
# 7                                        Aloo Raita
# 8                   Veg Raita | Mix Vegetable Raita
# 9                                    Lauki ka Raita
# 10                                     Carrot Raita
# 11                               Mango Raita Recipe
# 12            Vellarikka pachadi | Cucumber pachadi
# 13                                      Fruit Raita
# 14                        Mint Raita | Pudina Raita
# 15                        Masala Raita | Dahi Raita
# 16                                Pineapple Pachadi
# 17                      Palak Raita | Spinach Raita
#
#                                                 image  \
# 0   https://www.vegrecipesofindia.com/wp-content/u...
# 1   https://www.vegrecipesofindia.com/wp-content/u...
# 2   https://www.vegrecipesofindia.com/wp-content/u...
# 3   https://www.vegrecipesofindia.com/wp-content/u...
# 4   https://www.vegrecipesofindia.com/wp-content/u...
# 5   https://www.vegrecipesofindia.com/wp-content/u...
# 6   https://www.vegrecipesofindia.com/wp-content/u...
# 17                 Indian  Gluten Free, Vegetarian
#
#                                           ingredients  \
# 0   ▢ ½ cup boondi – plain or salted▢ 1 cup Curd (...
# 1   ▢ 1 cup Curd (yogurt) or any plant-based yogur...
# 2   For Onion Raita▢ 1 cup Curd (yogurt) – cold or...
# 3   ▢ 2 cups Curd (yogurt)▢ 1 beetroot medium-size...
# 4   ▢ 1 cup Curd (yogurt), cold or at room tempera...
# 5   ▢ 1 cup cucumber – finely chopped▢ 1 cup yogur...
# 6   ▢ 1 cup fresh chilled yogurt (curd)▢ ⅔ cup mak...
# 7   ▢ 1 cup Curd (yogurt) or 250 grams curd▢ 2 med...
# 8   ▢ 1 cup Curd (yogurt or dahi) – dairy or plant...
# 9   For Cooking Bottle Gourd▢ ¾ to 1 cup or (100 t...
# 10  main ingredients▢ 2 small to medium carrots – ...
# 11  ▢ 2 cups Curd (yogurt)▢ 2 tablespoons sugar – ...
# 12  for grinding▢ ¼  cup  grated fresh coconut▢ ¼ ...
# 13  ▢ ½  cup Curd (yogurt), cold or chilled – dair...
# 14  ▢ 1 cup Curd (dahi or yogurt) or 200 grams cur...
# 15  ▢ 1 cup fresh or chilled curd (yogurt) or 300 ...
# 16  For cooking pineapple▢ 1.25  cups  pineapple (...
# 17  ▢ 1 cup spinach (palak) – chopped and tightly ...
#
#                                          instructions  \
# 0   PreparationFirst warm water in a pan on stovet...
# 1   With a wired whisk, whip the curd till its smo...
# 2   Making Onion RaitaWhisk the curd (yogurt) till...
# 3   First prep your vegetables. Rinse them very we...
# 4   With a wired whisk whip the curd (yogurt) unti...
# 5   Rinse the cucumber. Then peel and finely chop ...
# 6   preparationHeat a small frying pan or kadai/wo...
# 7   Firstly boil 2 medium or 1 large potato in pre...
# 8   Rinse the vegetables first. Peel and finely ch...
# 9   Cooking bottle gourdRinse and peel bottle gour...
# 10  Rinse, peel and grate 2 small to medium carrot...
# 11  Make Mango RaitaIn a bowl, take the yogurt (da...
# 12  preparing coconut-mustard seeds pasteIn a grin...
# 13  In a bowl, whisk the yogurt (curd) till smooth...
# 14  preparation to make mint raitaTake 1 fresh cup...
# 15  In a small bowl take 1 cup fresh dahi (curd or...
# 16  Making coconut pasteIn a small grinder jar tak...
# 17  Sautéing PalakIn a bowl, whisk the curd or yog...
#
#                                             nutrition
# 0   NutritionCalories: 139kcal | Carbohydrates: 15...
# 1   NutritionCalories: 283kcal | Carbohydrates: 43...
# 2   NutritionCalories: 60kcal | Carbohydrates: 6g ...
# 3   NutritionCalories: 149kcal | Carbohydrates: 18...
# 4   NutritionCalories: 83kcal | Carbohydrates: 7g ...
# 5   NutritionCalories: 90kcal | Carbohydrates: 8g ...
# 6                                                None
# 7   NutritionCalories: 78kcal | Carbohydrates: 9g ...
# 8   NutritionCalories: 97kcal | Carbohydrates: 14g...
# 9   NutritionCalories: 60kcal | Carbohydrates: 6g ...
# 10  NutritionCalories: 120kcal | Carbohydrates: 13...
# 11  NutritionCalories: 276kcal | Carbohydrates: 39...
# 12  NutritionCalories: 72kcal | Carbohydrates: 5g ...
# 13  NutritionCalories: 304kcal | Carbohydrates: 68...
# 14  NutritionCalories: 86kcal | Carbohydrates: 8g ...
# 15  NutritionCalories: 91kcal | Carbohydrates: 9g ...
# 16  NutritionCalories: 91kcal | Carbohydrates: 7g ...
# 17  NutritionCalories: 83kcal | Carbohydrates: 5g ...

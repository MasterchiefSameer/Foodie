# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
import pandas as pd
from IPython.display import HTML

# %%
final_dict = {}
no_of_page = 1
for i in range(1 ,no_of_page + 1):
    
    #opening the page
    n = str(i)
    ext = '.html'
    file_path = 'r_' + n + ext
    with open(file_path, 'r', encoding='utf-8') as f:
        html_content = f.read()
        
    #scraping the page    
    soup = BeautifulSoup(html_content, 'lxml')
    t = soup.find_all('h2', class_='entry-title')
    dict = {}
    for j in t:
        x = j.find('a')
        dict[x.get_text()] = x.get('href')
    #merging the disctt to final dict
    final_dict.update(dict)
    print(f"page " + str(i) + " done")
# Out:
# page 1 done

# %%
len(final_dict)
# Out:
# 18

# %%
df_index = pd.DataFrame.from_dict(final_dict, orient='index')

# %%
df_index
# Out:
#                                                                                                  0
# Boondi Raita Recipe (Classic)                      https://www.vegrecipesofindia.com/boondi-raita/
# Pineapple Raita                                  https://www.vegrecipesofindia.com/pineapple-ra...
# Onion Raita | Tomato Raita | Onion Tomato Raita  https://www.vegrecipesofindia.com/onion-tomato...
# Beetroot Raita                                   https://www.vegrecipesofindia.com/beetroot-car...
# Burani Raita | Hyderabadi Burhani Raita          https://www.vegrecipesofindia.com/burhani-rait...
# Cucumber Raita Recipe (Indian Raita)             https://www.vegrecipesofindia.com/cucumber-rai...
# Makhana Raita                                    https://www.vegrecipesofindia.com/makhana-rait...
# Aloo Raita | Potato Raita                        https://www.vegrecipesofindia.com/aloo-raita-r...
# Veg Raita | Mix Vegetable Raita                  https://www.vegrecipesofindia.com/vegetable-ra...
# Lauki Ka Raita (Bottle Gourd Raita)              https://www.vegrecipesofindia.com/lauki-raita-...
# Carrot Raita | Gajar ka Raita                    https://www.vegrecipesofindia.com/carrot-raita...
# Mango Raita Recipe                               https://www.vegrecipesofindia.com/mango-raita-...
# Vellarikka Pachadi | Kerala Cucumber Pachadi     https://www.vegrecipesofindia.com/cucumber-pac...
# Fruit Raita                                      https://www.vegrecipesofindia.com/fruit-raita-...
# Mint Raita | Pudina Raita                        https://www.vegrecipesofindia.com/mint-raita-r...
# Masala Raita                                     https://www.vegrecipesofindia.com/masala-raita...
# Pineapple Pachadi                                https://www.vegrecipesofindia.com/pineapple-pa...
# Palak Raita | Spinach Raita                      https://www.vegrecipesofindia.com/palak-raita-...

# %%
df_index.to_csv('raita_links.csv')

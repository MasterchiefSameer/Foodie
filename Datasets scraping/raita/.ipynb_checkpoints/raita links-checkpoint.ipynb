# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
import pandas as pd
from IPython.display import HTML

# %%
final_dict = {}
no_of_page = 3
for i in range(1 ,no_of_page + 1):
    
    #opening the page
    n = str(i)
    ext = '.html'
    file_path = 'c_' + n + ext
    with open(file_path, 'r', encoding='utf-8') as f:
        html_content = f.read()
        
    #scraping the page    
    soup = BeautifulSoup(html_content, 'lxml')
    t = soup.find_all('h2', class_='entry-title')
    dict = {}
    for j in t:
        x = j.find('a')
        dict[x.get_text()] = x.get('href')
    #merging the disctt to final dict
    final_dict.update(dict)
    print(f"page " + str(i) + " done")
# Out:
# page 1 done
# page 2 done
# page 3 done

# %%
len(final_dict)
# Out:
# 141

# %%
df_index = pd.DataFrame.from_dict(final_dict, orient='index')

# %%
df_index
# Out:
#                                                                                                     0
# Paneer Butter Masala Recipe                         https://www.vegrecipesofindia.com/paneer-butte...
# Palak Paneer Recipe (Indian Cheese & Spinach)         https://www.vegrecipesofindia.com/palak-paneer/
# Matar Paneer Recipe (Punjabi Style Mutter Panee...    https://www.vegrecipesofindia.com/matar-paneer/
# Rajma Recipe | Rajma Masala (Restaurant Style)      https://www.vegrecipesofindia.com/rajma-masala...
# Malai Kofta Recipe (Restaurant Style Paneer Kofta)     https://www.vegrecipesofindia.com/malai-kofta/
# ...                                                                                               ...
# Aloo Matar Paneer                                   https://www.vegrecipesofindia.com/aloo-matar-p...
# Bendakaya Pulusu | Bendakaya Curry                  https://www.vegrecipesofindia.com/bendakaya-pu...
# Jain Palak Paneer                                   https://www.vegrecipesofindia.com/jain-palak-p...
# Soya Chunks Fry (Kerala Style Meal Maker Recipe)    https://www.vegrecipesofindia.com/soya-chunks-...
# Paneer Kali Mirch Recipe                            https://www.vegrecipesofindia.com/paneer-kalim...
#
# [141 rows x 1 columns]

# %%
df_index.to_csv('curry_links.csv')

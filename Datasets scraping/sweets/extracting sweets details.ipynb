# %%
import pandas as pd
import numpy as mp
import requests
from bs4 import BeautifulSoup

# %%
import time

# %%
df = pd.read_csv('sweets_links.csv')

# %%
df.rename(columns={'0': 'link'}, inplace=True)

# %%
link = df['link']

# %%
name = []
image = []
description = []
prep_time = []
cook_time = []
total_time = []
servings_number = []
servings_unit = []
course = []
cuisine = []
diet = []
ingredients = []
instructions = []
nutrition = []

# %%
count = 1;
for url in link:
    print(url)
    time.sleep(1)
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://www.google.com/'
    }
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    a = soup.find('div', class_='wprm-recipe-template-dassanas-veg-recipes-header-text')
    try:
        name.append(a.find('h2', class_='wprm-recipe-name wprm-block-text-bold').get_text(strip=True))
    except:
        continue
    try:
        # image.append(a.find("div", class_="wprm-recipe-image").find("img").get('data-lazy-src'))
        img_tag = soup.select_one(".wprm-recipe-image img")

        if img_tag:
            img_url = (
                img_tag.get("data-lazy-src")
                or img_tag.get("data-lazy-srcset")
                or img_tag.get("srcset")
            )
            image.append(img_url)
    except:
        image.append(None)
    description.append(a.find('div', class_='wprm-recipe-summary wprm-block-text-normal').get_text(strip=True))
    soup1 = soup.find('div', class_='wprm-recipe-template-dassanas-veg-recipes-meta')
    try:
        prep_time.append(soup1.find('span', class_='wprm-recipe-prep_time').get_text(strip=True))
    except:
        prep_time.append(None)
    try:
        cook_time.append(soup1.find('span', class_='wprm-recipe-cook_time').get_text(strip=True))
    except:
        cook_time.append(None)
    try:
        total_time.append(soup1.find('span', class_='wprm-recipe-total_time').get_text(strip=True))
    except:
        total_time.append(None)
    try:
        servings_number.append(soup1.find('span', class_='wprm-recipe-servings').get_text(strip=True))
    except:
        servings_number.append(None)
    try:
        servings_unit.append(soup1.find('span', class_='wprm-recipe-servings-unit').get_text(strip=True))
    except:
        servings_unit.append(None)
    try:
        course.append(soup1.find('span', class_='wprm-recipe-course').get_text(strip=True))
    except:
        course.append(None)
    try:
        cuisine.append(soup1.find('span', class_='wprm-recipe-cuisine').get_text(strip=True))
    except:
        cuisine.append(None)
    try:
        diet.append(soup1.find('span', class_='wprm-recipe-suitablefordiet').get_text(strip=True))
    except:
        diet.append(None)
    try:
        ingredients.append(soup.find('div', class_='wprm-recipe-ingredient-group').get_text())
    except:
        ingredients.append(None)
    try:
        instructions.append(soup.find('div', class_='wprm-internal-container wprm-internal-container-instructions').get_text())
    except:
        instructions.append(None)
    try:
        nutrition.append(soup.find('div', class_='wprm-nutrition-label-shortcode-container').get_text())
    except:
        nutrition.append(None)

    print(count)
    print(a.find('h2', class_='wprm-recipe-name wprm-block-text-bold').text)
    count += 1
# Out:
# https://www.vegrecipesofindia.com/besan-ladoo-recipe-easy-besan-ladoos/
# 1
# Besan Ladoo (Easy Besan ke Laddu Recipe)
# Sattu Ke Laddu | Sattu Ladoo
# https://www.vegrecipesofindia.com/mawa-modak-recipe-modak-recipes/
# 100
# Mawa Modak | Khoya Modak
# https://www.vegrecipesofindia.com/kesari-bhath-recipe/
# 101
# Kesari Bath Recipe | How To Make Kesari Bath
# https://www.vegrecipesofindia.com/sabudana-payasam-recipe/
# 102
# Javvarisi Payasam | Saggubiyyam Payasam | Sago Payasam
# https://www.vegrecipesofindia.com/ganesh-chaturthi-sweet-recipes/
# https://www.vegrecipesofindia.com/mango-kesari-recipe/
# 103
# Mango Kesari | Mango Sheera
# https://www.vegrecipesofindia.com/oats-kheer-recipe/
# 104
# Oats Kheer | Oats Payasam
# https://www.vegrecipesofindia.com/thekua-recipe/
# 105
# Thekua Recipe (Chaath Puja Special Sweet)
# https://www.vegrecipesofindia.com/double-ka-meetha-recipe/
# 106
# Double Ka Meetha
# https://www.vegrecipesofindia.com/semiya-payasam-recipe/
# 107
# Semiya Payasam Recipe (Vermicelli Payasam)
# https://www.vegrecipesofindia.com/raksha-bandhan-recipes/
# https://www.vegrecipesofindia.com/sweet-kozhukattai-recipe-chana-dal-modak/
# 108
# sweet kozhukattai
# https://www.vegrecipesofindia.com/kalkal-recipe/
# 109
# Kulkul Recipe | Eggless Kalkal Recipe
# https://www.vegrecipesofindia.com/janmashtami-fasting-recipes/
# https://www.vegrecipesofindia.com/jackfruit-payasam-recipe-chakka-payasam/
# 110
# Jackfruit Payasam | Chakka Payasam
# https://www.vegrecipesofindia.com/poornam-boorelu-recipe/
# 111
# Poornam Boorelu | Andhra Poornalu Recipe (Boorelu)
# https://www.vegrecipesofindia.com/mango-modak-recipe/
# 112
# Mango Modak
# https://www.vegrecipesofindia.com/pinni-recipe/
# 113
# Pinni Recipe (Pinni Sweet)
# https://www.vegrecipesofindia.com/elaneer-payasam/
# 114
# Elaneer Payasam Recipe (No Cook)
# https://www.vegrecipesofindia.com/bread-gulab-jamun-recipe/
# 115
# Bread Gulab Jamun
# https://www.vegrecipesofindia.com/wheat-porridge/
# 116
# Milk Dalia (Cracked Wheat Porridge)
# https://www.vegrecipesofindia.com/bread-halwa-recipe/
# 117
# Bread Halwa Recipe (Indian Bread Pudding)
# https://www.vegrecipesofindia.com/mango-halwa/
# 118
# Mango Halwa
# https://www.vegrecipesofindia.com/gajar-ka-murabba-recipe/
# 119
# Gajar ka Murabba | Carrot Murabba
# https://www.vegrecipesofindia.com/chocolate-sandesh-recipe/
# 120
# Chocolate Sandesh (With Cocoa Powder)
# https://www.vegrecipesofindia.com/gulab-jamun-easy-gulab-jamun-recipe/
# 121
# Gulab Jamun With Milk Powder
# https://www.vegrecipesofindia.com/chocolate-barfi-mithai/
# 122
# Chocolate Barfi Recipe (Mithai Burfi)

# %%
df = pd.DataFrame({
    'name': name,
    'image' : image,
    'description': description,
    'prep_time': prep_time,
    'cook_time': cook_time,
    'total_time': total_time,
    'servings_number': servings_number,
    'servings_unit': servings_unit,
    'course': course,
    'cuisine': cuisine,
    'diet': diet,
    'ingredients': ingredients,
    'instructions': instructions,
    'nutrition': nutrition
})

# %%
print("name:", len(name))
print("description:", len(description))
print("prep_time:", len(prep_time))
print("cook_time:", len(cook_time))
print("total_time:", len(total_time))
print("servings_number:", len(servings_number))
print("servings_unit:", len(servings_unit))
print("course:", len(course))
print("cuisine:", len(cuisine))
print("diet:", len(diet))
print("ingredients:", len(ingredients))
print("instructions:", len(instructions))
print("nutrition:", len(nutrition))
# Out:
# name: 122
# description: 122
# prep_time: 122
# cook_time: 122
# total_time: 122
# servings_number: 122
# servings_unit: 122
# course: 122
# cuisine: 122
# diet: 122
# ingredients: 122
# instructions: 122
# nutrition: 122

# %%
df.to_csv('sweets_details.csv')

# %%
df
# Out:
#                                                  name  \
# 0            Besan Ladoo (Easy Besan ke Laddu Recipe)
# 1    Gajar Ka Halwa (Traditional Carrot Halwa Recipe)
# 2          Kaju Katli Recipe | How to make Kaju Barfi
# 3                     Rasgulla Recipe (Soft & Spongy)
# 4                                     Moong Dal Halwa
# ..                                                ...
# 117                                       Mango Halwa
# 118                 Gajar ka Murabba | Carrot Murabba
# 119             Chocolate Sandesh (With Cocoa Powder)
# 120                      Gulab Jamun With Milk Powder
# 121             Chocolate Barfi Recipe (Mithai Burfi)
#
#                                                  image  \
# 0    https://www.vegrecipesofindia.com/wp-content/u...
# 1    https://www.vegrecipesofindia.com/wp-content/u...
# 2    https://www.vegrecipesofindia.com/wp-content/u...
# 3    https://www.vegrecipesofindia.com/wp-content/u...
# 4    https://www.vegrecipesofindia.com/wp-content/u...
# ..                                                 ...
# 117  https://www.vegrecipesofindia.com/wp-content/u...
# 118  https://www.vegrecipesofindia.com/wp-content/u...
# 119  https://www.vegrecipesofindia.com/wp-content/u...
# 120  https://www.vegrecipesofindia.com/wp-content/u...
# 121  https://www.vegrecipesofindia.com/wp-content/u...
#
#                                            description  prep_time  cook_time  \
# 0    Besan Ladoo or Besan ke Laddu is a popular Nor...   5minutes  25minutes
# 1    Gajar Ka Halwa is a classic North Indian sweet...  10minutes      1hour
# 2    These Kaju Katli are the way they are actually...   5minutes  15minutes
# 3    Rasgulla is a popular Bengali sweet and is als...  30minutes  10minutes
# 4    Moong Dal Halwa is an addictive and delicious ...  10minutes      1hour
# ..                                                 ...        ...        ...
# 117  Mango Halwa is a lovely homecooked, sweet and ...  15minutes  15minutes
# 118  Gajar ka murabba is a carrot preserve where fr...   5minutes  40minutes
# 119  Chocolate Sandesh is a chocolate based variati...  30minutes   6minutes
# 120  This Gulab Jamun With Milk Powder is a cheat's...  30minutes  20minutes
# 121  Chocolate Barfi (also spelled Chocolate Burfi)...   5minutes   5minutes
#
#     total_time servings_number             servings_unit            course  \
# 0    30minutes              15                     Ladoo            Sweets
# 1        1hour               6                      None  Desserts, Sweets
# 2    20minutes              14                Kaju Katli  Desserts, Sweets
# 3    40minutes              18                  Rasgulla          Desserts
# 4       7hours               6                      None          Desserts
# ..         ...             ...                       ...               ...
# 117  30minutes               6                      None          Desserts
# 118  45minutes               1                medium jar            Sweets
# 119  36minutes               9                   Sandesh            Sweets
# 120  50minutes              14  Milk Powder Gulab Jamuns            Sweets
# 121  10minutes              12           Chocolate Barfi            Sweets
#
#                    cuisine                            diet  \
# 0             North Indian         Gluten Free, Vegetarian
# 1    North Indian, Punjabi         Gluten Free, Vegetarian
# 2     Indian, North Indian  Gluten Free, Vegan, Vegetarian
# 3          Bengali, Indian         Gluten Free, Vegetarian
# 4             North Indian         Gluten Free, Vegetarian
# ..                     ...                             ...
# 117                 Indian                      Vegetarian
# 118  North Indian, Punjabi              Gluten Free, Vegan
# 119        Bengali, Indian         Gluten Free, Vegetarian
# 120           North Indian                      Vegetarian
# 121                 Indian                      Vegetarian
#
#                                            ingredients  \
# 0    ▢ 2 cups gram flour (besan) – 200 grams▢ ½ cup...
# 1    ▢ 8 to 9  carrots medium, juicy, tender – 650 ...
# 2    ▢ 1 cup/160  grams cashews (whole), at room te...
# 3    ▢ 1 litre whole milk▢ 2 to 3 tablespoons lemon...
# 4    Main ingredients▢ 1 cup moong dal (spilt huske...
# ..                                                 ...
# 117  ▢ 1 cup suji (fine textured rava or semolina)▢...
# 118  ▢ 500  grams  carrots  or 3.5 cups carrots▢ 25...
# 119  ▢ 300 to 350 grams Chenna or chenna made from ...
# 120  For the Jamun▢ 1  cup  milk powder▢ ¼  cup  al...
# 121  Main Ingredients▢ 200 grams (2 cups)  Khoya (m...
#
#                                           instructions  \
# 0    Roasting besanDry roast the besan in a heavy k...
# 1    PreparationFirst rinse, peel and then grate th...
# 2    Powdering CashewsAdd the cashews to a spice gr...
# 3    Making chennaTake whole milk in a pan and keep...
# 4    Making moong dal pasteSoak the moong dal or mu...
# ..                                                 ...
# 117  Powder the cardamom pods in a mortar pestle an...
# 118  Chopping carrotsRinse in water a few times and...
# 119  You will need fresh chenna to make the sandesh...
# 120  Making Sugar SyrupFirst mix the sugar, water, ...
# 121  PreparationSift powdered sugar and set aside.E...
#
#                                              nutrition
# 0    NutritionServing: 1besan ladoo | Calories: 155...
# 1    NutritionCalories: 328kcal | Carbohydrates: 42...
# 2    NutritionServing: 1kaju katli | Calories: 87kc...
# 3    NutritionCalories: 91kcal | Carbohydrates: 23g...
# 4    NutritionCalories: 662kcal | Carbohydrates: 10...
# ..                                                 ...
# 117  NutritionCalories: 311kcal | Carbohydrates: 49...
# 118  NutritionCalories: 1207kcal | Carbohydrates: 2...
# 119  NutritionCalories: 107kcal | Carbohydrates: 6g...
# 120  NutritionServing: 1gulab jamun | Calories: 144...
# 121  NutritionCalories: 101kcal | Carbohydrates: 11...
#
# [122 rows x 14 columns]

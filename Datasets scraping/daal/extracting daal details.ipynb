# %%
import pandas as pd
import numpy as mp
import requests
from bs4 import BeautifulSoup

# %%
import time

# %%
df = pd.read_csv('daal_links.csv')

# %%
df.rename(columns={'0': 'link'}, inplace=True)

# %%
link = df['link']

# %%
name = []
image = []
description = []
prep_time = []
cook_time = []
total_time = []
servings_number = []
servings_unit = []
course = []
cuisine = []
diet = []
ingredients = []
instructions = []
nutrition = []

# %%
count = 1;
for url in link:
    print(url)
    time.sleep(1)
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://www.google.com/'
    }
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    a = soup.find('div', class_='wprm-recipe-template-dassanas-veg-recipes-header-text')
    try:
        name.append(a.find('h2', class_='wprm-recipe-name wprm-block-text-bold').get_text(strip=True))
    except:
        continue
    try:
        # image.append(a.find("div", class_="wprm-recipe-image").find("img").get('data-lazy-src'))
        img_tag = soup.select_one(".wprm-recipe-image img")

        if img_tag:
            img_url = (
                img_tag.get("data-lazy-src")
                or img_tag.get("data-lazy-srcset")
                or img_tag.get("srcset")
            )
            image.append(img_url)
    except:
        image.append(None)
    description.append(a.find('div', class_='wprm-recipe-summary wprm-block-text-normal').get_text(strip=True))
    soup1 = soup.find('div', class_='wprm-recipe-template-dassanas-veg-recipes-meta')
    try:
        prep_time.append(soup1.find('span', class_='wprm-recipe-prep_time').get_text(strip=True))
    except:
        prep_time.append(None)
    try:
        cook_time.append(soup1.find('span', class_='wprm-recipe-cook_time').get_text(strip=True))
    except:
        cook_time.append(None)
    try:
        total_time.append(soup1.find('span', class_='wprm-recipe-total_time').get_text(strip=True))
    except:
        total_time.append(None)
    try:
        servings_number.append(soup1.find('span', class_='wprm-recipe-servings').get_text(strip=True))
    except:
        servings_number.append(None)
    try:
        servings_unit.append(soup1.find('span', class_='wprm-recipe-servings-unit').get_text(strip=True))
    except:
        servings_unit.append(None)
    try:
        course.append(soup1.find('span', class_='wprm-recipe-course').get_text(strip=True))
    except:
        course.append(None)
    try:
        cuisine.append(soup1.find('span', class_='wprm-recipe-cuisine').get_text(strip=True))
    except:
        cuisine.append(None)
    try:
        diet.append(soup1.find('span', class_='wprm-recipe-suitablefordiet').get_text(strip=True))
    except:
        diet.append(None)
    try:
        ingredients.append(soup.find('div', class_='wprm-recipe-ingredient-group').get_text())
    except:
        ingredients.append(None)
    try:
        instructions.append(soup.find('div', class_='wprm-internal-container wprm-internal-container-instructions').get_text())
    except:
        instructions.append(None)
    try:
        nutrition.append(soup.find('div', class_='wprm-nutrition-label-shortcode-container').get_text())
    except:
        nutrition.append(None)

    print(count)
    print(a.find('h2', class_='wprm-recipe-name wprm-block-text-bold').text)
    count += 1
# Out:
# https://www.vegrecipesofindia.com/dal-makhani-restaurant-style-recipe/
# 1
# Dal Makhani Recipe (Authentic Punjabi Style)
# https://www.vegrecipesofindia.com/restaurant-style-dal-tadka/
# 2
# Dal Tadka Recipe (Restaurant Style)
# https://www.vegrecipesofindia.com/rajma-masala-recipe-restaurant-style/
# 3
# Rajma Recipe | Rajma Masala (Restaurant Style)
# https://www.vegrecipesofindia.com/sambhar-recipe-a-method-made-easy/
# 58
# Parippu Curry | Lentil Curry
# https://www.vegrecipesofindia.com/varutharacha-sambar-recipe/
# 59
# Varutharacha Sambar
# https://www.vegrecipesofindia.com/lasooni-dal/
# 60
# Lasooni Dal Tadka (Garlic Dal)
# https://www.vegrecipesofindia.com/rajma-madra-recipe/
# 61
# Madra Recipe | Himachali Rajma Madra Recipe

# %%
df = pd.DataFrame({
    'name': name,
    'image' : image,
    'description': description,
    'prep_time': prep_time,
    'cook_time': cook_time,
    'total_time': total_time,
    'servings_number': servings_number,
    'servings_unit': servings_unit,
    'course': course,
    'cuisine': cuisine,
    'diet': diet,
    'ingredients': ingredients,
    'instructions': instructions,
    'nutrition': nutrition
})

# %%
print("name:", len(name))
print("description:", len(description))
print("prep_time:", len(prep_time))
print("cook_time:", len(cook_time))
print("total_time:", len(total_time))
print("servings_number:", len(servings_number))
print("servings_unit:", len(servings_unit))
print("course:", len(course))
print("cuisine:", len(cuisine))
print("diet:", len(diet))
print("ingredients:", len(ingredients))
print("instructions:", len(instructions))
print("nutrition:", len(nutrition))
# Out:
# name: 61
# description: 61
# prep_time: 61
# cook_time: 61
# total_time: 61
# servings_number: 61
# servings_unit: 61
# course: 61
# cuisine: 61
# diet: 61
# ingredients: 61
# instructions: 61
# nutrition: 61

# %%
df
# Out:
#                                               name  \
# 0     Dal Makhani Recipe (Authentic Punjabi Style)
# 1              Dal Tadka Recipe (Restaurant Style)
# 2   Rajma Recipe | Rajma Masala (Restaurant Style)
# 3                        Traditional Sambar Recipe
# 4                 Chana Dal Recipe (Punjabi Style)
# ..                                             ...
# 56        Rajma Sundal (Kidney Beans With Coconut)
# 57                    Parippu Curry | Lentil Curry
# 58                             Varutharacha Sambar
# 59                  Lasooni Dal Tadka (Garlic Dal)
# 60     Madra Recipe | Himachali Rajma Madra Recipe
#
#                                                 image  \
# 0   https://www.vegrecipesofindia.com/wp-content/u...
# 1   https://www.vegrecipesofindia.com/wp-content/u...
# 2   https://www.vegrecipesofindia.com/wp-content/u...
# 3   https://www.vegrecipesofindia.com/wp-content/u...
# 4   https://www.vegrecipesofindia.com/wp-content/u...
# ..                                                ...
# 56  https://www.vegrecipesofindia.com/wp-content/u...
# 57  https://www.vegrecipesofindia.com/wp-content/u...
# 58  https://www.vegrecipesofindia.com/wp-content/u...
# 59  https://www.vegrecipesofindia.com/wp-content/u...
# 60  https://www.vegrecipesofindia.com/wp-content/u...
#
#                                           description  prep_time  cook_time  \
# 0   This Dal Makhani recipe is a restaurant style ...     8hours      1hour
# 1   This restaurant style Dal Tadka recipe is of a...  20minutes  10minutes
# 2   This Rajma recipe is a creamy, tangy and spice...     9hours  45minutes
# 3   Sambar is a traditional South Indian stew made...  15minutes  30minutes
# 4   This Chana Dal is Punjabi style recipe of beng...  10minutes  20minutes
# ..                                                ...        ...        ...
# 56  Rajma Sundal recipe is a South Indian preparat...   5minutes  30minutes
# 57  Parippu Curry is simply a Moong Lentil Curry t...   5minutes  20minutes
# 58  Kerala varutharacha sambar is a delicious vari...  25minutes  20minutes
# 59  Lasooni Dal Tadka is a mildly spiced and tempe...  20minutes   5minutes
# 60  Rajma madra recipe is is a curd and legume bas...  20minutes  20minutes
#
#    total_time servings_number servings_unit       course  \
# 0      9hours               4          None  Main Course
# 1   30minutes               4          None  Main Course
# 2      9hours               5          None  Main Course
# 3   45minutes               4          None  Main Course
# 4       1hour               4          None  Main Course
# ..        ...             ...           ...          ...
# 56     8hours               4          None       Snacks
# 57  25minutes               3          None  Main Course
# 58  45minutes               6          None  Main Course
# 59  25minutes               4          None  Main Course
# 60  40minutes               4          None  Main Course
#
#                      cuisine                     diet  \
# 0      North Indian, Punjabi  Gluten Free, Vegetarian
# 1               North Indian        Vegan, Vegetarian
# 2      North Indian, Punjabi               Vegetarian
# 3   South Indian, Tamil Nadu                    Vegan
# 4               North Indian        Vegan, Vegetarian
# ..                       ...                      ...
# 56              South Indian                    Vegan
# 57      Kerala, South Indian       Gluten Free, Vegan
# 58      Kerala, South Indian                     None
# 59                    Indian               Vegetarian
# 60   Himachali, North Indian               Vegetarian
#
#                                           ingredients  \
# 0   For Cooking Lentils▢ ¾ cup or 140 grams whole ...
# 1   For cooking lentils▢ 1 cup or (200 grams)  tuv...
# 2   For pressure cooking▢ 1 cup rajma – 200 grams ...
# 3   For tamarind pulp▢ 1 tablespoon tamarind▢ ⅓ cu...
# 4   For cooking lentils▢ 1 cup chana dal (bengal g...
# ..                                                ...
# 56  For pressure cooking▢ 1 cup kidney beans (rajm...
# 57  For pressure cooking lentils▢ ⅓ cup moong dal ...
# 58  for pressure cooking▢ ⅓ cup  tuvar dal (arhar ...
# 59  For Cooking Lentils▢ ½ cup arhar dal (pigeon p...
# 60  for cooking rajma▢ 1  cup  rajma (kidney beans...
#
#                                          instructions  \
# 0   Preparation & Cooking LentilsSoak both the who...
# 1   Cook lentilsThoroughly rinse tuvar dal (tur da...
# 2   SoakingRinse and soak the rajma (kidney beans)...
# 3   Making tamarind pulpSoak the tamarind in hot w...
# 4   Cooking LentilsPick and rinse the chana dal we...
# ..                                                ...
# 56  PreparationRinse and soak the kidney beans ove...
# 57  Pressure cooking moong lentilsRinse moong dal ...
# 58  pressure cooking dalRinse ⅓ cup tuvar dal a co...
# 59  Cooking lentilsRinse the tur dal in water 3 to...
# 60  pressure cooking rajma for madra recipeRinse 1...
#
#                                             nutrition
# 0   NutritionCalories: 308kcal | Carbohydrates: 35...
# 1   NutritionCalories: 213kcal | Carbohydrates: 16...
# 2   NutritionCalories: 210kcal | Carbohydrates: 28...
# 3   NutritionCalories: 265kcal | Carbohydrates: 38...
# 4   NutritionCalories: 272kcal | Carbohydrates: 34...
# ..                                                ...
# 56  NutritionCalories: 214kcal | Carbohydrates: 32...
# 57  NutritionCalories: 173kcal | Carbohydrates: 20...
# 58  NutritionCalories: 214kcal | Carbohydrates: 23...
# 59  NutritionCalories: 125kcal | Carbohydrates: 14...
# 60  NutritionCalories: 259kcal | Carbohydrates: 33...
#
# [61 rows x 14 columns]

# %%
df.to_csv('daal_details.csv')

# %%
df['image'][2]
# Out:
# 'https://www.vegrecipesofindia.com/wp-content/uploads/2021/05/rajma-recipe-2-280x280.jpg'

# %%
df['image'][4]
# Out:
# 'https://www.vegrecipesofindia.com/wp-content/uploads/2015/01/dal-makhani-recipe-1-280x280.jpg'

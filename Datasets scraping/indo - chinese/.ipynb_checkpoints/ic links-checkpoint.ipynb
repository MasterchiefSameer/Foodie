# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
import pandas as pd
from IPython.display import HTML

# %%
final_dict = {}
no_of_page = 1
for i in range(1 ,no_of_page + 1):
    
    #opening the page
    n = str(i)
    ext = '.html'
    file_path = 'ic_' + n + ext
    with open(file_path, 'r', encoding='utf-8') as f:
        html_content = f.read()
        
    #scraping the page    
    soup = BeautifulSoup(html_content, 'lxml')
    t = soup.find_all('h2', class_='entry-title')
    dict = {}
    for j in t:
        x = j.find('a')
        dict[x.get_text()] = x.get('href')
    #merging the disctt to final dict
    final_dict.update(dict)
    print(f"page " + str(i) + " done")
# Out:
# page 1 done

# %%
len(final_dict)
# Out:
# 39

# %%
df_index = pd.DataFrame.from_dict(final_dict, orient='index')

# %%
df_index
# Out:
#                                                                                                     0
# Manchurian Recipe | Veg Manchurian Gravy            https://www.vegrecipesofindia.com/veg-manchuri...
# Veg Fried Rice Recipe (Chinese Style)               https://www.vegrecipesofindia.com/veg-fried-ri...
# Schezwan Sauce Recipe (Spicy Schezwan Chutney)      https://www.vegrecipesofindia.com/schezwan-sau...
# Spring Rolls | Crispy Veg Spring Roll Recipe        https://www.vegrecipesofindia.com/spring-rolls...
# Sweet Corn Soup Recipe (Easy & Homemade)            https://www.vegrecipesofindia.com/sweet-corn-s...
# Veg Noodles (Stir Fried Vegetable Noodles)          https://www.vegrecipesofindia.com/veg-noodles-...
# Spring Roll Sheets | Spring Roll Wrappers Recipe    https://www.vegrecipesofindia.com/spring-roll-...
# Gobi Manchurian Recipe                              https://www.vegrecipesofindia.com/gobi-manchur...
# Hakka Noodles Recipe                                https://www.vegrecipesofindia.com/vegetable-ha...
# Hot and Sour Soup                                   https://www.vegrecipesofindia.com/veg-hot-and-...
# Baby Corn Manchurian (Dry & Gravy)                  https://www.vegrecipesofindia.com/baby-corn-ma...
# Mushroom Manchurian (Indo Chinese Recipe)           https://www.vegrecipesofindia.com/mushroom-man...
# Manchow Soup Recipe | Spicy Veg Manchow Soup        https://www.vegrecipesofindia.com/veg-manchow-...
# Chilli Baby Corn Recipe (Spicy & Crispy)            https://www.vegrecipesofindia.com/chilli-baby-...
# Chow Mein Recipe (Vegetarian)                       https://www.vegrecipesofindia.com/veg-chow-mei...
# Schezwan Fried Rice Recipe                          https://www.vegrecipesofindia.com/veg-schezwan...
# Paneer Manchurian (Dry & Gravy)                     https://www.vegrecipesofindia.com/paneer-manch...
# Schezwan Noodles Recipe (Street Style)              https://www.vegrecipesofindia.com/schezwan-noo...
# Chilli Mushroom Recipe (Stovetop & Instant Pot)     https://www.vegrecipesofindia.com/chilli-mushr...
# Chilli Paneer Recipe (Restaurant Style)             https://www.vegrecipesofindia.com/chilli-panee...
# Chilli Garlic Noodles | Asian Garlic Noodles        https://www.vegrecipesofindia.com/chilli-garli...
# Sweet And Sour Vegetables                           https://www.vegrecipesofindia.com/sweet-sour-v...
# Sesame Toast                                        https://www.vegrecipesofindia.com/sesame-veg-t...
# Noodle Soup | Vegetable Noodle Soup                 https://www.vegrecipesofindia.com/veg-noodle-s...
# Mushroom Noodles Recipe                             https://www.vegrecipesofindia.com/mushroom-noo...
# Chinese Mushroom In Spicy Sauce                     https://www.vegrecipesofindia.com/garlic-mushr...
# Chilli Idli Recipe                                  https://www.vegrecipesofindia.com/chilli-idli-...
# American Chop Suey Recipe                           https://www.vegrecipesofindia.com/veg-american...
# Chilli Potato                                        https://www.vegrecipesofindia.com/chilli-potato/
# Burnt Garlic Fried Rice                             https://www.vegrecipesofindia.com/burnt-garlic...
# Schezwan Paneer                                     https://www.vegrecipesofindia.com/paneer-schez...
# Corn Fried Rice Recipe (Indo Chinese Style)         https://www.vegrecipesofindia.com/sweet-corn-f...
# Chilli Gobi (Cauliflower Chilli)                       https://www.vegrecipesofindia.com/chilli-gobi/
# Singapore Noodles – Veg Singapore Mei Fun           https://www.vegrecipesofindia.com/singapore-no...
# Singapore Fried Rice                                https://www.vegrecipesofindia.com/singapore-fr...
# Chinese Pakoda | Cabbage Manchurian                 https://www.vegrecipesofindia.com/chinese-pako...
# Idli Manchurian                                     https://www.vegrecipesofindia.com/idli-manchur...
# Fried Noodles (DIY) | How To Make Crispy Fried ...  https://www.vegrecipesofindia.com/how-to-make-...
# Chinese Bhel (Street Style)                         https://www.vegrecipesofindia.com/chinese-bhel...

# %%
df_index.to_csv('ic_links.csv')

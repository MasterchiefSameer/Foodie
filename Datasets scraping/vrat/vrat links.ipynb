# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
import pandas as pd
from IPython.display import HTML

# %%
final_dict = {}
no_of_page = 1
for i in range(1 ,no_of_page + 1):
    
    #opening the page
    n = str(i)
    ext = '.html'
    file_path = 'vrat_' + n + ext
    with open(file_path, 'r', encoding='utf-8') as f:
        html_content = f.read()
        
    #scraping the page    
    soup = BeautifulSoup(html_content, 'lxml')
    t = soup.find_all('h2', class_='entry-title')
    dict = {}
    for j in t:
        x = j.find('a')
        dict[x.get_text()] = x.get('href')
    #merging the disctt to final dict
    final_dict.update(dict)
    print(f"page " + str(i) + " done")
# Out:
# page 1 done

# %%
len(final_dict)
# Out:
# 47

# %%
df_index = pd.DataFrame.from_dict(final_dict, orient='index')

# %%
df_index
# Out:
#                                                                                                     0
# Navratri Fasting Rules, Recipes & Pooja Vidhi |...  https://www.vegrecipesofindia.com/navratri-fas...
# Sabudana Khichdi Recipe                             https://www.vegrecipesofindia.com/sabudana-khi...
# Kaddu ki Sabji (Easy Pumpkin Recipe)                https://www.vegrecipesofindia.com/kaddu-ki-sabzi/
# Sabudana Vada Recipe (For Fasting)                  https://www.vegrecipesofindia.com/sabudana-vad...
# Navratri Recipes | 84 Navratri Fast Recipes         https://www.vegrecipesofindia.com/navratri-rec...
# Lauki Halwa Recipe (Bottle Gourd Halwa)             https://www.vegrecipesofindia.com/lauki-halwa-...
# Sabudana Kheer | How to make Sabudana Kheer         https://www.vegrecipesofindia.com/sabudana-khe...
# Arbi Sabji | Arbi Recipe | Ghuiya Ki Sabji          https://www.vegrecipesofindia.com/sukhi-arbi-r...
# Sweet Potato Cutlet | Sweet Potato Tikki            https://www.vegrecipesofindia.com/sweet-potato...
# Easy Aloo ki Sabji | Satvik Aloo Tamatar Ki Sabji   https://www.vegrecipesofindia.com/aloo-tamatar...
# Makhana Recipe – Roasted Phool Makhana Recipe       https://www.vegrecipesofindia.com/roasted-makh...
# Sama Chawal Idli | Vrat Ki Idli | Vari Rice Idli    https://www.vegrecipesofindia.com/sama-ke-chaw...
# Sabudana Thalipeeth (Maharashtrian Fasting Snack)   https://www.vegrecipesofindia.com/sabudana-tha...
# Farali Pattice                                      https://www.vegrecipesofindia.com/farali-patti...
# Sweet Potato Halwa (Shakarkandi ka Halwa)           https://www.vegrecipesofindia.com/sweet-potato...
# Kaddu ki Kheer (Pumpkin Payasam)                    https://www.vegrecipesofindia.com/pumpkin-khee...
# Samak Rice Pulao (Barnyard Millet Recipe)           https://www.vegrecipesofindia.com/vrat-ke-chaw...
# Kuttu Khichdi | Buckwheat Khichdi                   https://www.vegrecipesofindia.com/buckwheat-kh...
# Sabudana Chivda Recipe | Sabudana Namkeen Recip...  https://www.vegrecipesofindia.com/sabudana-chi...

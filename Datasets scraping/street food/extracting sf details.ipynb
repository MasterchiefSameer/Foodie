# %%
import pandas as pd
import numpy as mp
import requests
from bs4 import BeautifulSoup

# %%
import time

# %%
df = pd.read_csv('sf_links.csv')

# %%
df.rename(columns={'0': 'link'}, inplace=True)

# %%
link = df['link']

# %%
name = []
image = []
description = []
prep_time = []
cook_time = []
total_time = []
servings_number = []
servings_unit = []
course = []
cuisine = []
diet = []
ingredients = []
instructions = []
nutrition = []

# %%
count = 1;
for url in link:
    print(url)
    time.sleep(1)
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://www.google.com/'
    }
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    a = soup.find('div', class_='wprm-recipe-template-dassanas-veg-recipes-header-text')
    try:
        name.append(a.find('h2', class_='wprm-recipe-name wprm-block-text-bold').get_text(strip=True))
    except:
        continue
    try:
        # image.append(a.find("div", class_="wprm-recipe-image").find("img").get('data-lazy-src'))
        img_tag = soup.select_one(".wprm-recipe-image img")

        if img_tag:
            img_url = (
                img_tag.get("data-lazy-src")
                or img_tag.get("data-lazy-srcset")
                or img_tag.get("srcset")
            )
            image.append(img_url)
    except:
        image.append(None)
    description.append(a.find('div', class_='wprm-recipe-summary wprm-block-text-normal').get_text(strip=True))
    soup1 = soup.find('div', class_='wprm-recipe-template-dassanas-veg-recipes-meta')
    try:
        prep_time.append(soup1.find('span', class_='wprm-recipe-prep_time').get_text(strip=True))
    except:
        prep_time.append(None)
    try:
        cook_time.append(soup1.find('span', class_='wprm-recipe-cook_time').get_text(strip=True))
    except:
        cook_time.append(None)
    try:
        total_time.append(soup1.find('span', class_='wprm-recipe-total_time').get_text(strip=True))
    except:
        total_time.append(None)
    try:
        servings_number.append(soup1.find('span', class_='wprm-recipe-servings').get_text(strip=True))
    except:
        servings_number.append(None)
    try:
        servings_unit.append(soup1.find('span', class_='wprm-recipe-servings-unit').get_text(strip=True))
    except:
        servings_unit.append(None)
    try:
        course.append(soup1.find('span', class_='wprm-recipe-course').get_text(strip=True))
    except:
        course.append(None)
    try:
        cuisine.append(soup1.find('span', class_='wprm-recipe-cuisine').get_text(strip=True))
    except:
        cuisine.append(None)
    try:
        diet.append(soup1.find('span', class_='wprm-recipe-suitablefordiet').get_text(strip=True))
    except:
        diet.append(None)
    try:
        ingredients.append(soup.find('div', class_='wprm-recipe-ingredient-group').get_text())
    except:
        ingredients.append(None)
    try:
        instructions.append(soup.find('div', class_='wprm-internal-container wprm-internal-container-instructions').get_text())
    except:
        instructions.append(None)
    try:
        nutrition.append(soup.find('div', class_='wprm-nutrition-label-shortcode-container').get_text())
    except:
        nutrition.append(None)

    print(count)
    print(a.find('h2', class_='wprm-recipe-name wprm-block-text-bold').text)
    count += 1
# Out:
# https://www.vegrecipesofindia.com/idli-recipe-how-to-make-soft-idlis/
# 1
# Idli Recipe with Batter – Traditional + Key Tips
# https://www.vegrecipesofindia.com/pav-bhaji-recipe-mumbai-pav-bhaji-a-fastfood-recipe-from-mumbai/
# 2
# Pav Bhaji Recipe (Buttery & Spicy Mumbai Classic)
# https://www.vegrecipesofindia.com/samosa-recipe-punjabi-samosa/
# 3
# Samosa Recipe (Crispy Aloo Samosa)
# https://www.vegrecipesofindia.com/pani-puri-recipe-golgappa-pani-puri/
# 4
# Puri For Pani Puri | Suji Ke Golgappe
# https://www.vegrecipesofindia.com/veg-momos-recipe-vegetable-momos/
# 5
# Veg Momos Recipe (Indian Street Style)
# https://www.vegrecipesofindia.com/rava-dosa-crisp-rava-dosa/
# 6
# Rava Dosa Recipe (Quick & Crispy)
# https://www.vegrecipesofindia.com/pani-puri-recipe-mumbai-pani-puri-recipe/
# 7
# Pani Puri
# https://www.vegrecipesofindia.com/dahi-vada-recipe/
# 8
# Dahi Vada Recipe (Authentic)
# https://www.vegrecipesofindia.com/spring-rolls-recipe-veg-spring-rolls/
# 9
# Spring Rolls | Crispy Veg Spring Roll Recipe
# https://www.vegrecipesofindia.com/veg-burger-recipe-veggie-burger/
# 10
# Burger Recipe | Veggie Burger
# https://www.vegrecipesofindia.com/matar-kachori-khasta-matar-kachori/
# 11
# Matar Kachori Recipe (Green Peas Kachori)
# https://www.vegrecipesofindia.com/aloo-kulcha-recipe/
# 12
# Aloo Kulcha
# https://www.vegrecipesofindia.com/dabeli-recipe-kutchi-dabeli-recipe/
# 13
# Dabeli Recipe | Kacchi Dabeli | Dabeli Masala
# https://www.vegrecipesofindia.com/veg-noodles-recipe-easy-veg-noodles/
# 14
# Veg Noodles (Stir Fried Vegetable Noodles)
# https://www.vegrecipesofindia.com/tawa-pulao-recipe-pulao-recipes/
# 15
# Tawa Pulao (Mumbai Style)
# https://www.vegrecipesofindia.com/vegetable-cutlet-easy-veg-cutlet-recipe/
# 16
# Veg Cutlet Recipe | Mix Vegetable Cutlet
# https://www.vegrecipesofindia.com/vegetable-hakka-noodles-recipe/
# 17
# Hakka Noodles Recipe (Indian Chinese Style)
# https://www.vegrecipesofindia.com/misal-pav-recipe-misal-pav/
# 18
# Misal Pav (Misal Recipe)
# https://www.vegrecipesofindia.com/bhel-puri-mumbai-bhel-puri/
# 19
# Bhel Puri Recipe (Mumbai Street Style)
# https://www.vegrecipesofindia.com/malpua-recipe-malpua-rabdi/
# 20
# Malpua Recipe (Classic Homemade Sweet)
# https://www.vegrecipesofindia.com/aloo-tikki-aloo-pattice-recipe-made-from-leftover-potatoes/
# 21
# Aloo Tikki Recipe (Indian Potato Patties)
# https://www.vegrecipesofindia.com/bombay-toast-sandwich/
# 22
# Mumbai Masala Sandwich | Bombay Masala Toast Sandwich
# https://www.vegrecipesofindia.com/dosa-recipe-dosa-batter-recipe/
# 23
# Dosa Recipe & Dosa Batter Recipe
# https://www.vegrecipesofindia.com/bombay-veg-sandwich/
# 24
# Bombay Sandwich Recipe (Street Style)
# https://www.vegrecipesofindia.com/ragda-patties-recipe-mumbai-ragda-patties-recipe/
# 25
# Ragda Patties Recipe (Mumbai Style Ragda Pattice)
# https://www.vegrecipesofindia.com/fruit-chaat-recipe-fruit-chaat/
# 26
# Fruit Chaat Recipe (Delhi Street Style)
# https://www.vegrecipesofindia.com/veg-chow-mein-noodles-recipe/
# 27
# Chow Mein Recipe (Vegetarian)
# https://www.vegrecipesofindia.com/aloo-tikki-burger/
# https://www.vegrecipesofindia.com/pav-bhaji-dosa/
# 115
# Pav Bhaji Dosa (Street Style)
# https://www.vegrecipesofindia.com/chinese-bhel-recipe/
# 116
# Chinese Bhel Recipe (Street Style)
# https://www.vegrecipesofindia.com/mix-dal-vada/
# 117
# Mix Dal Vada (Soft & Spongy)

# %%
df = pd.DataFrame({
    'name': name,
    'image' : image,
    'description': description,
    'prep_time': prep_time,
    'cook_time': cook_time,
    'total_time': total_time,
    'servings_number': servings_number,
    'servings_unit': servings_unit,
    'course': course,
    'cuisine': cuisine,
    'diet': diet,
    'ingredients': ingredients,
    'instructions': instructions,
    'nutrition': nutrition
})

# %%
print("name:", len(name))
print("description:", len(description))
print("prep_time:", len(prep_time))
print("cook_time:", len(cook_time))
print("total_time:", len(total_time))
print("servings_number:", len(servings_number))
print("servings_unit:", len(servings_unit))
print("course:", len(course))
print("cuisine:", len(cuisine))
print("diet:", len(diet))
print("ingredients:", len(ingredients))
print("instructions:", len(instructions))
print("nutrition:", len(nutrition))
# Out:
# name: 117
# description: 117
# prep_time: 117
# cook_time: 117
# total_time: 117
# servings_number: 117
# servings_unit: 117
# course: 117
# cuisine: 117
# diet: 117
# ingredients: 117
# instructions: 117
# nutrition: 117

# %%
df.to_csv('sf_details.csv')

# %%
df
# Out:
#                                                   name  \
# 0     Idli Recipe with Batter – Traditional + Key Tips
# 1    Pav Bhaji Recipe (Buttery & Spicy Mumbai Classic)
# 2                   Samosa Recipe (Crispy Aloo Samosa)
# 3                Puri For Pani Puri | Suji Ke Golgappe
# 4               Veg Momos Recipe (Indian Street Style)
# ..                                                 ...
# 112               Dahi ke Sholay (Crispy Yogurt Rolls)
# 113                                      Fried Noodles
# 114                      Pav Bhaji Dosa (Street Style)
# 115                 Chinese Bhel Recipe (Street Style)
# 116                       Mix Dal Vada (Soft & Spongy)
#
#                                                  image  \
# 0    https://www.vegrecipesofindia.com/wp-content/u...
# 1    https://www.vegrecipesofindia.com/wp-content/u...
# 2    https://www.vegrecipesofindia.com/wp-content/u...
# 3    https://www.vegrecipesofindia.com/wp-content/u...
# 4    https://www.vegrecipesofindia.com/wp-content/u...
# ..                                                 ...
# 112  https://www.vegrecipesofindia.com/wp-content/u...
# 113  https://www.vegrecipesofindia.com/wp-content/u...
# 114  https://www.vegrecipesofindia.com/wp-content/u...
# 115  https://www.vegrecipesofindia.com/wp-content/u...
# 116  https://www.vegrecipesofindia.com/wp-content/u...
#
#                                            description  prep_time  cook_time  \
# 0    Idli is a classic South Indian breakfast dish ...     9hours  25minutes
# 1    Pav Bhaji is a hearty, delightsome, flavorful ...  20minutes  20minutes
# 2    A traditional Punjabi samosa is a deep-fried, ...  45minutes  45minutes
# 3    These are crispy fried sooji ke golgappe or pu...  15minutes  30minutes
# 4    Veg Momos are steamed dumplings stuffed with a...  30minutes      1hour
# ..                                                 ...        ...        ...
# 112  Dahi ke Sholay is a popular Delhi street snack...  20minutes  30minutes
# 113  Crisp fried noodles are often made when making...   5minutes  20minutes
# 114  Pav Bhaji Dosa is a variation of dosa famous i...   5minutes  30minutes
# 115  Chinese Bhel is an adaptation of the American ...   5minutes  10minutes
# 116  A tasty recipe of Mix Dal Vada made with the g...     6hours  30minutes
#
#     total_time servings_number       servings_unit  \
# 0       9hours              30                Idli
# 1    40minutes               5                None
# 2        1hour              12              Samosa
# 3        1hour              50    Suji Ke Golgappe
# 4        1hour              15               Momos
# ..         ...             ...                 ...
# 112  50minutes              10               Rolls
# 113  25minutes               2  cups fried noodles
# 114  35minutes               4                None
# 115  15minutes               2                None
# 116     6hours               3                None
#
#                                     course                            cuisine  \
# 0                        Breakfast, Snacks                       South Indian
# 1    Brunch, Main Course, Snacks, Starters  Indian Street Food, Maharashtrian
# 2                         Snacks, Starters              North Indian, Punjabi
# 3                                   Snacks                             Indian
# 4                       Appetizers, Snacks             Indian, Tibetan, World
# ..                                     ...                                ...
# 112                                 Snacks                 Indian Street Food
# 113                                 Snacks                       Indo Chinese
# 114                         Brunch, Snacks         Indian, Mumbai Street Food
# 115                       Snacks, Starters   Indian Street Food, Indo Chinese
# 116                                 Snacks                             Indian
#
#                                diet  \
# 0    Gluten Free, Vegan, Vegetarian
# 1                        Vegetarian
# 2                        Vegetarian
# 3                             Vegan
# 4        Low Fat, Vegan, Vegetarian
# ..                              ...
# 112                      Vegetarian
# 113                           Vegan
# 114                      Vegetarian
# 115                           Vegan
# 116                           Vegan
#
#                                            ingredients  \
# 0    ▢ 1 cup regular rice  + 1 cup parboiled rice o...
# 1    For making bhaji (vegetable gravy)▢ 3 medium-s...
# 2    For making samosa pastry▢ 2 cups (250 grams)  ...
# 3    ▢ 1 cup sooji (rava or semolina), fine and unr...
# 4    for the dumpling dough▢ 1 cup all-purpose flou...
# ..                                                 ...
# 112  For Hung Curd Filling▢ 2 cups Curd (dahi), ful...
# 113  ▢ 100  grams  noodles  – instant, whole wheat,...
# 114  ▢ 1 large bowl Dosa Batter or idli-dosa batter...
# 115  For frying noodles▢ 75  grams  noodles  (hakka...
# 116  ▢ ½ cup urad dal (husked & split black gram)▢ ...
#
#                                           instructions  \
# 0    Soaking rice and lentilsPick and rinse both th...
# 1    Cooking veggiesRinse, peel and chop the veggie...
# 2    Making samosa pastry doughTake the flour, caro...
# 3    Making suji puri doughIn a mixing bowl, take t...
# 4    Making doughTake the all-purpose flour, salt, ...
# ..                                                 ...
# 112  Prepare Hung CurdPlace the curd in a muslin cl...
# 113  cooking noodlesTake 3.5 cups water in a sauce ...
# 114  On a well seasoned tawa (griddle) or a flat sk...
# 115  Boiling noodlesHeat 3 cups water together with...
# 116  Soak the lentils overnight in enough water ove...
#
#                                              nutrition
# 0    NutritionCalories: 38kcal | Carbohydrates: 8g ...
# 1    NutritionCalories: 531kcal | Carbohydrates: 88...
# 2    NutritionServing: 1samosa | Calories: 175kcal ...
# 3    NutritionCalories: 21kcal | Carbohydrates: 3g ...
# 4    NutritionCalories: 53kcal | Carbohydrates: 9g ...
# ..                                                 ...
# 112  NutritionCalories: 156kcal | Carbohydrates: 15...
# 113  NutritionCalories: 333kcal | Carbohydrates: 45...
# 114                                               None
# 115  NutritionCalories: 544kcal | Carbohydrates: 54...
# 116  NutritionCalories: 378kcal | Carbohydrates: 44...
#
# [117 rows x 14 columns]

# %%
import pandas as pd
import numpy as mp
import requests
from bs4 import BeautifulSoup

# %%
import time

# %%
df = pd.read_csv('veggies_links.csv')

# %%
df.rename(columns={'0': 'link'}, inplace=True)

# %%
link = df['link']

# %%
name = []
image = []
description = []
prep_time = []
cook_time = []
total_time = []
servings_number = []
servings_unit = []
course = []
cuisine = []
diet = []
ingredients = []
instructions = []
nutrition = []

# %%
count = 1;
for url in link:
    print(url)
    time.sleep(1)
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://www.google.com/'
    }
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    a = soup.find('div', class_='wprm-recipe-template-dassanas-veg-recipes-header-text')
    try:
        name.append(a.find('h2', class_='wprm-recipe-name wprm-block-text-bold').get_text(strip=True))
    except:
        continue
    try:
        # image.append(a.find("div", class_="wprm-recipe-image").find("img").get('data-lazy-src'))
        img_tag = soup.select_one(".wprm-recipe-image img")

        if img_tag:
            img_url = (
                img_tag.get("data-lazy-src")
                or img_tag.get("data-lazy-srcset")
                or img_tag.get("srcset")
            )
            image.append(img_url)
    except:
        image.append(None)
    description.append(a.find('div', class_='wprm-recipe-summary wprm-block-text-normal').get_text(strip=True))
    soup1 = soup.find('div', class_='wprm-recipe-template-dassanas-veg-recipes-meta')
    try:
        prep_time.append(soup1.find('span', class_='wprm-recipe-prep_time').get_text(strip=True))
    except:
        prep_time.append(None)
    try:
        cook_time.append(soup1.find('span', class_='wprm-recipe-cook_time').get_text(strip=True))
    except:
        cook_time.append(None)
    try:
        total_time.append(soup1.find('span', class_='wprm-recipe-total_time').get_text(strip=True))
    except:
        total_time.append(None)
    try:
        servings_number.append(soup1.find('span', class_='wprm-recipe-servings').get_text(strip=True))
    except:
        servings_number.append(None)
    try:
        servings_unit.append(soup1.find('span', class_='wprm-recipe-servings-unit').get_text(strip=True))
    except:
        servings_unit.append(None)
    try:
        course.append(soup1.find('span', class_='wprm-recipe-course').get_text(strip=True))
    except:
        course.append(None)
    try:
        cuisine.append(soup1.find('span', class_='wprm-recipe-cuisine').get_text(strip=True))
    except:
        cuisine.append(None)
    try:
        diet.append(soup1.find('span', class_='wprm-recipe-suitablefordiet').get_text(strip=True))
    except:
        diet.append(None)
    try:
        ingredients.append(soup.find('div', class_='wprm-recipe-ingredient-group').get_text())
    except:
        ingredients.append(None)
    try:
        instructions.append(soup.find('div', class_='wprm-internal-container wprm-internal-container-instructions').get_text())
    except:
        instructions.append(None)
    try:
        nutrition.append(soup.find('div', class_='wprm-nutrition-label-shortcode-container').get_text())
    except:
        nutrition.append(None)

    print(count)
    print(a.find('h2', class_='wprm-recipe-name wprm-block-text-bold').text)
    count += 1
# Out:
# https://www.vegrecipesofindia.com/pav-bhaji-recipe-mumbai-pav-bhaji-a-fastfood-recipe-from-mumbai/
# 1
# Pav Bhaji Recipe (Buttery & Spicy Mumbai Classic)
# 125
# Cauliflower Curry (North Indian Style)
# https://www.vegrecipesofindia.com/ennegayi-recipe-badanekayi-ennegayi-recipe/
# 126
# Ennegayi Recipe | Badanekayi Ennegayi
# https://www.vegrecipesofindia.com/poricha-kootu-recipe/
# 127
# Poosanikai Kootu | Poricha Kootu
# https://www.vegrecipesofindia.com/kathal-ki-sabji-recipe/
# 128
# Kathal ki Sabji
# https://www.vegrecipesofindia.com/aloo-potol-er-dalna-recipe/
# 129
# Potol Recipe | Bengali Aloo Potol er Dalna
# https://www.vegrecipesofindia.com/kung-pao-vegetables-recipe/
# 130
# Kung Pao Recipe | Kung Pao Vegetables
# https://www.vegrecipesofindia.com/scallion-pancakes/
# 131
# Scallion Pancake | Green Onion Pancake
# https://www.vegrecipesofindia.com/methi-bhaji-recipe/
# 132
# Methi Bhaji | Methi ki Bhaji
# https://www.vegrecipesofindia.com/valor-papdi-nu-shaak-recipe/
# 133
# Sem Ki Sabji | Surti Papdi Recipe | Valor Papdi Shaak
# https://www.vegrecipesofindia.com/rishi-panchami-bhaji-recipe/
# 134
# Rishi Panchami Bhaji | Rushichi Bhaji
# https://www.vegrecipesofindia.com/kaddu-recipes-pumpkin-recipes/
# https://www.vegrecipesofindia.com/potato-salad/
# 135
# Potato Salad Recipe With Creamy Mayo Dressing
# https://www.vegrecipesofindia.com/bharwan-tinda-recipe/
# 136
# Tinda Recipe | Bharwa Tinda Recipe
# https://www.vegrecipesofindia.com/veg-lollipop-recipe/
# 137
# Veg Lollipop
# https://www.vegrecipesofindia.com/baby-corn-sabji/
# 138
# Baby Corn Sabji
# https://www.vegrecipesofindia.com/kovakkai-poriyal/
# 139
# Kovakkai Poriyal
# https://www.vegrecipesofindia.com/bhindi-fry/
# 140
# Bhindi Fry
# https://www.vegrecipesofindia.com/banana-varuval-recipe/
# 141
# Vazhakkai Fry | Vazhakkai Varuval
# https://www.vegrecipesofindia.com/bhendi-chi-bhaji/
# 142
# Bhendi Chi Bhaji (Bhindi Bhaji)
# https://www.vegrecipesofindia.com/breadfruit-recipe-kadachakka-recipe/
# 143
# Fried Breadfruit Recipe
# https://www.vegrecipesofindia.com/gajar-recipes-carrot-recipes/
# https://www.vegrecipesofindia.com/kappa-puzhukku-recipe/
# 144
# Kappa Puzhukku | Maravalli Kilangu Recipe (Mashed Tapioca Root)
# https://www.vegrecipesofindia.com/chawli-bhaji-recipe-phali-ki-sabzi/
# 145
# Barbati ki Sabji | Long Beans Recipe
# https://www.vegrecipesofindia.com/cauliflower-poriyal/
# 146
# Cauliflower Poriyal (South Indian Cauliflower Stir Fry)
# https://www.vegrecipesofindia.com/chinese-pakoda-recipe/
# 147
# Chinese Pakoda | Cabbage Manchurian
# https://www.vegrecipesofindia.com/baby-corn-recipes/
# https://www.vegrecipesofindia.com/bhogichi-bhaji-recipe/
# 148
# Bhogichi Bhaji

# %%
df = pd.DataFrame({
    'name': name,
    'image' : image,
    'description': description,
    'prep_time': prep_time,
    'cook_time': cook_time,
    'total_time': total_time,
    'servings_number': servings_number,
    'servings_unit': servings_unit,
    'course': course,
    'cuisine': cuisine,
    'diet': diet,
    'ingredients': ingredients,
    'instructions': instructions,
    'nutrition': nutrition
})

# %%
print("name:", len(name))
print("description:", len(description))
print("prep_time:", len(prep_time))
print("cook_time:", len(cook_time))
print("total_time:", len(total_time))
print("servings_number:", len(servings_number))
print("servings_unit:", len(servings_unit))
print("course:", len(course))
print("cuisine:", len(cuisine))
print("diet:", len(diet))
print("ingredients:", len(ingredients))
print("instructions:", len(instructions))
print("nutrition:", len(nutrition))
# Out:
# name: 148
# description: 148
# prep_time: 148
# cook_time: 148
# total_time: 148
# servings_number: 148
# servings_unit: 148
# course: 148
# cuisine: 148
# diet: 148
# ingredients: 148
# instructions: 148
# nutrition: 148

# %%
df.to_csv('veggies_details.csv')

# %%
df
# Out:
#                                                   name  \
# 0    Pav Bhaji Recipe (Buttery & Spicy Mumbai Classic)
# 1             Manchurian Recipe | Veg Manchurian Gravy
# 2                                Kadai Mushroom Recipe
# 3                            Traditional Sambar Recipe
# 4              Bhindi Masala Recipe (Restaurant Style)
# ..                                                 ...
# 143  Kappa Puzhukku | Maravalli Kilangu Recipe (Mas...
# 144               Barbati ki Sabji | Long Beans Recipe
# 145  Cauliflower Poriyal (South Indian Cauliflower ...
# 146                Chinese Pakoda | Cabbage Manchurian
# 147                                     Bhogichi Bhaji
#
#                                                  image  \
# 0    https://www.vegrecipesofindia.com/wp-content/u...
# 1    https://www.vegrecipesofindia.com/wp-content/u...
# 2    https://www.vegrecipesofindia.com/wp-content/u...
# 3    https://www.vegrecipesofindia.com/wp-content/u...
# 4    https://www.vegrecipesofindia.com/wp-content/u...
# ..                                                 ...
# 143  https://www.vegrecipesofindia.com/wp-content/u...
# 144  https://www.vegrecipesofindia.com/wp-content/u...
# 145  https://www.vegrecipesofindia.com/wp-content/u...
# 146  https://www.vegrecipesofindia.com/wp-content/u...
# 147  https://www.vegrecipesofindia.com/wp-content/u...
#
#                                            description  prep_time  cook_time  \
# 0    Pav Bhaji is a hearty, delightsome, flavorful ...  20minutes  20minutes
# 1    Manchurian Recipe is a tasty Indo Chinese prep...  40minutes  20minutes
# 2    Kadai Mushroom Recipe is a quick and flavorful...  10minutes  20minutes
# 3    Sambar is a traditional South Indian stew made...  15minutes  30minutes
# 4    Bhindi Masala recipe is a North Indian, Punjab...  20minutes  25minutes
# ..                                                 ...        ...        ...
# 143  Simple, delicious and nutritious Tapioca recip...  10minutes  20minutes
# 144  Barbati ki Sabji is a simple dry preparation o...   5minutes  30minutes
# 145  Here’s an easy, tasty dish in South Indian cui...  15minutes  25minutes
# 146  Chinese pakoda are crisp and spiced fried vege...  10minutes  20minutes
# 147  Bhogi chi bhaji is a mix vegetable curry that ...  15minutes  30minutes
#
#     total_time servings_number servings_unit  \
# 0    40minutes               5          None
# 1        1hour               3          None
# 2    30minutes               3          None
# 3    45minutes               4          None
# 4    45minutes               3          None
# ..         ...             ...           ...
# 143  30minutes               3          None
# 144      1hour               4          None
# 145  40minutes               3          None
# 146  30minutes               3          None
# 147  20minutes               6          None
#
#                                     course  \
# 0    Brunch, Main Course, Snacks, Starters
# 1                              Main Course
# 2                              Main Course
# 3                              Main Course
# 4                                Side Dish
# ..                                     ...
# 143                 Main Course, Side Dish
# 144                              Side Dish
# 145                              Side Dish
# 146                       Snacks, Starters
# 147                            Main Course
#
#                                     cuisine                            diet  \
# 0         Indian Street Food, Maharashtrian                      Vegetarian
# 1                              Indo Chinese                           Vegan
# 2                     North Indian, Punjabi              Gluten Free, Vegan
# 3                  South Indian, Tamil Nadu                           Vegan
# 4                     North Indian, Punjabi  Gluten Free, Vegan, Vegetarian
# ..                                      ...                             ...
# 143                    Kerala, South Indian              Gluten Free, Vegan
# 144        Konkani & Malvani, Maharashtrian                           Vegan
# 145                South Indian, Tamil Nadu                           Vegan
# 146  Indian Street Food, Mumbai Street Food                      Vegetarian
# 147                           Maharashtrian                            None
#
#                                            ingredients  \
# 0    For making bhaji (vegetable gravy)▢ 3 medium-s...
# 1    For vegetable balls▢ ½ cup carrot – grated▢ ½ ...
# 2    For kadai masala▢ 1 tablespoon coriander seeds...
# 3    For tamarind pulp▢ 1 tablespoon tamarind▢ ⅓ cu...
# 4    For sautéing ▢ 2 tablespoons oil – sunflower o...
# ..                                                 ...
# 143  For cooking kappa (tapioca root, yuca)▢ 1   ta...
# 144  ▢ 1.5 tablespoon oil▢ ½ teaspoon mustard seeds...
# 145  For Blanching Cauliflower▢ 3½ cups cauliflower...
# 146  ▢ 1 cup tightly packed finely chopped cabbage ...
# 147  to roast and ground:▢ 2  tablespoons  white se...
#
#                                           instructions  \
# 0    Cooking veggiesRinse, peel and chop the veggie...
# 1    Making vegetable ballsTake the finely chopped ...
# 2    Making kadai masalaFirst dry roast/toast all t...
# 3    Making tamarind pulpSoak the tamarind in hot w...
# 4    PreparationRinse the bhindi (okra) well in wat...
# ..                                                 ...
# 143  Cooking and Mashing Tapioca RootTake the tapio...
# 144  PreparationFirst rinse chana dal in water for ...
# 145  Prepping CauliflowerRinse and chop the caulifl...
# 146  making chinese pakoda mixtureRinse, peel and t...
# 147  chopping veggies for bhogichi bhaji recipe:Fir...
#
#                                              nutrition
# 0    NutritionCalories: 531kcal | Carbohydrates: 88...
# 1    NutritionCalories: 224kcal | Carbohydrates: 23...
# 2    NutritionCalories: 197kcal | Carbohydrates: 11...
# 3    NutritionCalories: 265kcal | Carbohydrates: 38...
# 4    NutritionCalories: 176kcal | Carbohydrates: 11...
# ..                                                 ...
# 143  NutritionCalories: 287kcal | Carbohydrates: 56...
# 144  NutritionCalories: 133kcal | Carbohydrates: 14...
# 145  NutritionCalories: 185kcal | Carbohydrates: 10...
# 146  NutritionCalories: 223kcal | Carbohydrates: 27...
# 147  NutritionCalories: 353kcal | Carbohydrates: 54...
#
# [148 rows x 14 columns]
